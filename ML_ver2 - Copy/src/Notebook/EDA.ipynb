# %%
"""
🎨 Enhanced ML Template v2.1 - Interactive Visualization Experience
──────────────────────────────────────────────────────────────────
✨ Features:
   • Interactive Plotly visualizations with theme support
   • Beautiful styled tables and outputs
   • Auto-profiling capabilities
   • SHAP model explainability
   • Performance optimizations
   • Multiple theme options (light, dark, professional, vibrant)

📚 Quick Navigation: Run this cell and scroll to sections
"""

# Setup notebook styling first
import sys
sys.path.append('..')

# Import enhanced utilities
from utils.display_tools import (
    setup_notebook_style, 
    print_header, 
    print_info,
    create_navigation_menu,
    set_plotly_renderer
)
from utils.theme import list_themes, switch_theme

# Configure notebook with theme (change theme here!)
# Options: 'light', 'dark', 'professional', 'vibrant', 'ocean', 'sunset', 'forest', 'minimal'
setup_notebook_style(theme="dark", performance_mode=False)

# Set Plotly renderer for better performance
set_plotly_renderer("notebook_connected")

# Core imports
import pandas as pd
import numpy as np
import seaborn as sns
from core.EDA import EDA

# Visualization imports
import plotly.express as px
import plotly.graph_objects as go

print_header("🎯 ML TEMPLATE v2.1 - ENHANCED VISUALIZATION", level=1, emoji="✨")
print_info("💡 TIP: Scroll down for Quick Navigation menu", type='tip')
# Out:
# ⚠️ Theme 'ocean' not found. Using 'light' theme.
# ☀️ Theme Loaded: Modern Light
#     <style>
#         :root {
#             --bg-color: #ffffff;
#             --text-color: #2c3e50;
#         }
#         .container { width:95% !important; }
#         .output_png { display: table-cell; text-align: center; vertical-align: middle; }
#         div.output_scroll { height: 600px; }
#         body { background-color: var(--bg-color); color: var(--text-color); }
#         div.output_area { background-color: var(--bg-color); }
#         .rendered_html { color: var(--text-color); }
#
#         /* Better code cell styling */
#         div.input_area {
#             border-radius: 5px;
#             border-left: 3px solid #1f77b4;
#         }
#
#         /* Prettier tables */
#         table {
#             border-collapse: collapse;
#             width: 100%;
#             margin: 10px 0;
#         }
#
#         th, td {
#             padding: 10px;
#             text-align: left;
# ...

# %%
# 📑 QUICK NAVIGATION
# Click on sections below to jump directly!

from utils.display_tools import create_navigation_menu

create_navigation_menu({
    '📂 Data Loading': 2,
    '👀 Data Overview': 3,
    '🔍 Missing Values': 4,
    '🔗 Correlation Matrix': 6,
    '📊 Auto Profiling (Optional)': 7,
    '🤖 Model Training': 9,
    '📈 Enhanced Evaluation': 10,
    '🔬 SHAP Analysis (Optional)': 11,
    '📊 Dashboard Demo': 12
})
# Out:
#     <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%);
#                 padding: 20px; border-radius: 10px; margin: 20px 0;">
#         <h2 style="color: white; margin: 0 0 15px 0;">📑 Quick Navigation</h2>
#         <div style="display: flex; flex-wrap: wrap; gap: 10px;">
#
#         <a href="#" onclick="Jupyter.notebook.scroll_to_cell(2); return false;"
#            style="background: white; color: #667eea; padding: 10px 15px;
#                   border-radius: 5px; text-decoration: none; font-weight: bold;
#                   box-shadow: 0 2px 5px rgba(0,0,0,0.2);">
#             📂 Data Loading
#         </a>
#
#         <a href="#" onclick="Jupyter.notebook.scroll_to_cell(3); return false;"
#            style="background: white; color: #667eea; padding: 10px 15px;
#                   border-radius: 5px; text-decoration: none; font-weight: bold;
#                   box-shadow: 0 2px 5px rgba(0,0,0,0.2);">
#             👀 Data Overview
#         </a>
#
# ...

# %% [markdown]
# ---
# ## 🎨 Theme System Demo
# You can switch themes anytime! Try different themes below:
# ---

# %%
# 🎨 View all available themes
from utils.theme import list_themes
list_themes()

# To switch theme, uncomment and run:
# from utils.theme import switch_theme
# switch_theme("dark", performance_mode=False)  # Try: dark, professional, vibrant, ocean, sunset
# Out:
# 🎨 Available Themes:
# ...
#   • light           → Modern Light
#   • dark            → Modern Dark
#   • professional    → Professional
#   • vibrant         → Vibrant
# ...

# %%
train_data = pd.read_csv("../../Data/Raw/train.csv")
# test_data = pd.read_csv("Data/Raw/test.csv")

# %%
eda_train = EDA(train_data)
# eda_test = EDA(test_data)

# %%
eda_train.overview()
# Out:
# ...
# 📊 📊 TỔNG QUAN DỮ LIỆU
# ...
#
# 📏 Kích thước dữ liệu: 1,460 rows × 81 columns
# 💾 Memory usage: 3.43 MB
#
# 🧩 Kiểu dữ liệu:
#    • object: 43 columns
#    • int64: 35 columns
#    • float64: 3 columns
#
# 📋 Thống kê mô tả:
#
# Statistical Summary
# ...
# ╒═══════════════╤══════════╤══════════╤═════════╤══════════╤════════════╤═══════════╤═══════════╤════════════╤════════════╤════════════╤════════════╕
# │               │    count │   unique │ top     │     freq │       mean │       std │       min │        25% │        50% │        75% │        max │
# ╞═══════════════╪══════════╪══════════╪═════════╪══════════╪════════════╪═══════════╪═══════════╪════════════╪════════════╪════════════╪════════════╡
# │ Id            │ 1460.000 │  nan     │ nan     │  nan     │    730.500 │   421.610 │     1.000 │    365.750 │    730.500 │   1095.250 │   1460.000 │
# ...

# %%
eda_train.missing_values()
# Out:
# --------------------------------------------------------------------------------
# 🔍 🔍 KIỂM TRA GIÁ TRỊ THIẾU
# --------------------------------------------------------------------------------
#
# ⚠️ Phát hiện 19 cột có giá trị thiếu
#
# 📉 Các cột có giá trị thiếu
# ...
# ╒══════════════╤═════════════════╤══════════════╕
# │              │   Missing Count │   Percentage │
# ╞══════════════╪═════════════════╪══════════════╡
# │ PoolQC       │        1453.000 │       99.520 │
# ├──────────────┼─────────────────┼──────────────┤
# │ MiscFeature  │        1406.000 │       96.300 │
# ├──────────────┼─────────────────┼──────────────┤
# │ Alley        │        1369.000 │       93.770 │
# ├──────────────┼─────────────────┼──────────────┤
# │ Fence        │        1179.000 │       80.750 │
# ├──────────────┼─────────────────┼──────────────┤
# │ MasVnrType   │         872.000 │       59.730 │
# ├──────────────┼─────────────────┼──────────────┤
# │ FireplaceQu  │         690.000 │       47.260 │
# ...

# %%
train_data.drop({'PoolQC', 'MiscFeature', 'Alley', 'Fence', 'FireplaceQu','MasVnrType','LotFrontage','GarageType','GarageYrBlt','GarageFinish','GarageQual','GarageCond','BsmtFinType2','BsmtExposure','BsmtFinType1','BsmtCond','BsmtQual','MasVnrArea','Electrical'}, axis=1, inplace=True)

# %%
# 🎨 Demo: Interactive Correlation Matrix (Plotly)
print_header("🔗 INTERACTIVE CORRELATION MATRIX", level=2, emoji="🔗")
print_info("Hover over cells to see exact correlation values!", type='tip')

eda_train.correlation_matrix()
# Out:
# --------------------------------------------------------------------------------
# 🔗 🔗 INTERACTIVE CORRELATION MATRIX
# --------------------------------------------------------------------------------
#
# 💡 Hover over cells to see exact correlation values!
#
# --------------------------------------------------------------------------------
# 🔗 🔗 MA TRẬN TƯƠNG QUAN
# --------------------------------------------------------------------------------
# ...

# %%
# 💡 OPTIONAL: Generate Auto-Profiling Report
# Uncomment to create a comprehensive HTML report

print_header("🔬 AUTO PROFILING (OPTIONAL)", level=2, emoji="🔬")
print_info("This will generate a comprehensive HTML report. May take a few minutes.", type='info')

# eda_train.run_profiling(output_html="../../Reports/EDA_Report.html", minimal=True)

print_info("⏭️ Skipped for now. Uncomment to generate report.", type='warning')
# Out:
# --------------------------------------------------------------------------------
# 🔬 🔬 AUTO PROFILING (OPTIONAL)
# --------------------------------------------------------------------------------
#
# ℹ️ This will generate a comprehensive HTML report. May take a few minutes.
# ⚠️ ⏭️ Skipped for now. Uncomment to generate report.

# %%
eda_train.correlation_matrix()
# Out:
# --------------------------------------------------------------------------------
# 🔗 🔗 MA TRẬN TƯƠNG QUAN
# --------------------------------------------------------------------------------
# ...

# %%
# 🎯 ENHANCED MODEL EVALUATION DEMO
print_header("🎯 ENHANCED MODEL EVALUATION", level=1, emoji="🚀")

from model.LightGBM import ModelLightGBM

# Train model
lgbm = ModelLightGBM()
lgbm.train(train_data, target_col='SalePrice')

print_info("✅ Model training complete!", type='success')
print_info("💡 All evaluation plots are now interactive with Plotly!", type='tip')
# Out:
# ...
# 🚀 🎯 ENHANCED MODEL EVALUATION
# ...

# %%
# 📊 Demo: Enhanced Evaluation with Residuals Analysis
print_header("📊 COMPREHENSIVE EVALUATION", level=2, emoji="📊")

from Evaluation.Evaluation import Evaluation

# Create evaluator with plotly enabled
X_train, X_test, y_train, y_test = lgbm.prepare_data(train_data, 'SalePrice')
evaluator = Evaluation(
    model=lgbm.model,
    X_test=X_test,
    y_test=y_test,
    model_name="LightGBM Enhanced",
    task="regression",
    use_plotly=True
)

# Run full evaluation with residuals
metrics = evaluator.full_evaluation(
    feature_names=X_train.columns.tolist(),
    show_residuals=True,
    show_shap=False  # Set to True to enable SHAP analysis
)

print_info("✨ Interactive plots allow you to zoom, pan, and export!", type='success')
# Out:
# --------------------------------------------------------------------------------
# 📊 📊 COMPREHENSIVE EVALUATION
# --------------------------------------------------------------------------------
#
#
# ...
# 🎯 🎯 FULL EVALUATION: LIGHTGBM ENHANCED
# ...
#
#
# ...
# 🔹 🔹 EVALUATION REPORT: LIGHTGBM ENHANCED (REGRESSION)
# ...
#
#
# 📈 LightGBM Enhanced Metrics
# ...
# ╒══════════╤════════════╕
# │ Metric   │      Score │
# ╞══════════╪════════════╡
# │ MAE      │ 17911.7915 │
# ├──────────┼────────────┤
# │ RMSE     │ 29063.6386 │
# ├──────────┼────────────┤
# │ RMSLE    │     0.1468 │
# ├──────────┼────────────┤
# │ R²       │     0.8899 │
# ╘══════════╧════════════╛
# ...
#
# --------------------------------------------------------------------------------
# 📈 📈 PREDICTED VS ACTUAL
# --------------------------------------------------------------------------------
# ...

# %%
# 🔬 OPTIONAL: SHAP Explainability Analysis
print_header("🔬 MODEL EXPLAINABILITY WITH SHAP", level=2, emoji="🔬")
print_info("SHAP provides detailed feature contribution analysis", type='info')

# Uncomment to run SHAP analysis (may take a few minutes)
# evaluator.show_shap_summary(plot_type='dot', max_display=20)

print_info("⏭️ Skipped for now. Uncomment to see SHAP analysis.", type='warning')
print_info("💡 Tip: SHAP works best with tree-based models like LightGBM!", type='tip')
# Out:
# --------------------------------------------------------------------------------
# 🔬 🔬 MODEL EXPLAINABILITY WITH SHAP
# --------------------------------------------------------------------------------
#
# ℹ️ SHAP provides detailed feature contribution analysis
# ⚠️ ⏭️ Skipped for now. Uncomment to see SHAP analysis.
# 💡 💡 Tip: SHAP works best with tree-based models like LightGBM!

# %%
# 📊 BONUS: Quick Dashboard Demo
print_header("📊 DASHBOARD DEMO", level=2, emoji="📊")

from dashboard import quick_eda_dashboard, show_target_analysis_dashboard

# Quick comprehensive dashboard
# Uncomment to see full dashboard with overview, correlations, and target analysis
# quick_eda_dashboard(train_data, target_col='SalePrice')

# Or show specific dashboard
print_info("Showing target analysis dashboard...", type='info')
show_target_analysis_dashboard(train_data, 'SalePrice')

print_info("✨ Dashboard complete! Explore the interactive visualizations.", type='success')
# Out:
# --------------------------------------------------------------------------------
# 📊 📊 DASHBOARD DEMO
# --------------------------------------------------------------------------------
#
# ℹ️ Showing target analysis dashboard...
#
# ...
# 🎯 🎯 TARGET ANALYSIS: SALEPRICE
# ...

# %%
from model.Lasso import ModelLasso
lasso = ModelLasso()
X_train, X_test, y_train, y_test = lassoll.prepare_data(train_data, 'SalePrice')
lasso.train(train_data, 'SalePrice')
from model.LightGBM import ModelLightGBM

lgbm = ModelLightGBM()
lgbm.train(train_data, target_col="SalePrice")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 3
#       1 from model.Lasso import ModelLasso
#       2 lasso = ModelLasso()
# ----> 3 X_train, X_test, y_train, y_test = lassoll.prepare_data(train_data, 'SalePrice')
#       4 lasso.train(train_data, 'SalePrice')
#       5 from model.LightGBM import ModelLightGBM
#
# NameError: name 'lassoll' is not defined

# %%
from model.LightGBM import ModelLightGBM
from Tracking.Tracking import Tracking
lgbm = ModelLightGBM()
lgbm.train(train_data, target_col='SalePrice')

with Tracking(backend="mlflow", project="RegressionProject", model=lgbm.model) as tracker:
    tracker.log_params(lgbm.best_params)   # dict best_params của GridSearch
    tracker.log_metrics(lgbm.metrics)
    tracker.save_model()
# Out:
# 🔍 Đang tìm hyperparameters tốt nhất...
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001922 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2992
# [LightGBM] [Info] Number of data points in the train set: 1168, number of used features: 116
# [LightGBM] [Info] Start training from score 181441.541952
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
