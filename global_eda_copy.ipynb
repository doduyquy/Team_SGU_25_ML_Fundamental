# %% [markdown]
# # 📊 Demo EDA Module - House Prices Dataset
#
# Notebook này demo các chức năng của module EDA để phân tích dữ liệu House Prices.

# %%
# Import thư viện cần thiết
import pandas as pd
import numpy as np
import sys
import os

# Thêm đường dẫn src vào sys.path
sys.path.append(os.path.abspath('../src'))

# Import module EDA
from eda.eda import EDA

print("✅ Import thành công!")
# Out:
# ✅ Import thành công!

# %% [markdown]
# ## 📂 Load Dữ Liệu
#
# Load dữ liệu train và test từ thư mục data/raw/

# %%
# Load dữ liệu train và test
train_path = '../data/raw/train.csv'
test_path = '../data/raw/test.csv'

df_train = pd.read_csv(train_path)
df_test = pd.read_csv(test_path)

print(f"📊 Train shape: {df_train.shape}")
print(f"📊 Test shape: {df_test.shape}")

# Hiển thị một vài dòng đầu
print("\n🔍 Xem dữ liệu train:")
df_train.head()
# Out:
# 📊 Train shape: (1460, 81)
# 📊 Test shape: (1459, 80)
#
# 🔍 Xem dữ liệu train:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %% [markdown]
# ## 🔍 Demo 1: Tổng Quan Dữ Liệu (Overview)
#
# Sử dụng phương thức `overview()` để xem tổng quan về dataset.

# %%
# Khởi tạo EDA cho train dataset
eda_train = EDA(df_train)

# Xem tổng quan
eda_train.overview()
# Out:
# # 📊 Tổng Quan Dữ Liệu
# **📊 Thông tin Dataset**
# <style type="text/css">
# #T_96a67 th {
#   background-color: #4CAF50;
#   color: white;
#   font-weight: bold;
#   text-align: center;
#   padding: 10px;
# }
# #T_96a67 td {
#   text-align: center;
# }
# #T_96a67  {
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_96a67_row0_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_96a67_row0_col1 {
#   background-color: #b30d26;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_96a67_row0_col2 {
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_96a67_row0_col3, #T_96a67_row0_col4 {
#   background-color: #a50026;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# </style>
# <table id="T_96a67">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_96a67_level0_col0" class="col_heading level0 col0" >📏 Số dòng</th>
#       <th id="T_96a67_level0_col1" class="col_heading level0 col1" >📋 Số cột</th>
#       <th id="T_96a67_level0_col2" class="col_heading level0 col2" >💾 Bộ nhớ (MB)</th>
#       <th id="T_96a67_level0_col3" class="col_heading level0 col3" >🔢 Biến số</th>
#       <th id="T_96a67_level0_col4" class="col_heading level0 col4" >📝 Biến phân loại</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_96a67_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_96a67_row0_col0" class="data row0 col0" >1460</td>
#       <td id="T_96a67_row0_col1" class="data row0 col1" >81</td>
#       <td id="T_96a67_row0_col2" class="data row0 col2" >3.43</td>
#       <td id="T_96a67_row0_col3" class="data row0 col3" >38</td>
#       <td id="T_96a67_row0_col4" class="data row0 col4" >43</td>
#     </tr>
#   </tbody>
# </table>
# **🗂️ Chi tiết các cột**
# <style type="text/css">
# #T_10bf9 th {
#   background-color: #4CAF50;
#   color: white;
#   font-weight: bold;
#   text-align: center;
#   padding: 10px;
# }
# #T_10bf9 td {
#   text-align: center;
# }
# #T_10bf9  {
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_10bf9_row0_col0, #T_10bf9_row0_col1, #T_10bf9_row0_col4, #T_10bf9_row1_col0, #T_10bf9_row1_col1, #T_10bf9_row1_col4, #T_10bf9_row2_col0, #T_10bf9_row2_col1, #T_10bf9_row2_col4, #T_10bf9_row3_col0, #T_10bf9_row3_col1, #T_10bf9_row3_col4, #T_10bf9_row4_col0, #T_10bf9_row4_col1, #T_10bf9_row4_col4, #T_10bf9_row5_col0, #T_10bf9_row5_col1, #T_10bf9_row5_col4, #T_10bf9_row6_col0, #T_10bf9_row6_col1, #T_10bf9_row6_col4, #T_10bf9_row7_col0, #T_10bf9_row7_col1, #T_10bf9_row7_col4, #T_10bf9_row8_col0, #T_10bf9_row8_col1, #T_10bf9_row8_col4, #T_10bf9_row9_col0, #T_10bf9_row9_col1, #T_10bf9_row9_col4, #T_10bf9_row10_col0, #T_10bf9_row10_col1, #T_10bf9_row10_col4, #T_10bf9_row11_col0, #T_10bf9_row11_col1, #T_10bf9_row11_col4, #T_10bf9_row12_col0, #T_10bf9_row12_col1, #T_10bf9_row12_col4, #T_10bf9_row13_col0, #T_10bf9_row13_col1, #T_10bf9_row13_col4, #T_10bf9_row14_col0, #T_10bf9_row14_col1, #T_10bf9_row14_col4, #T_10bf9_row15_col0, #T_10bf9_row15_col1, #T_10bf9_row15_col4, #T_10bf9_row16_col0, #T_10bf9_row16_col1, #T_10bf9_row16_col4, #T_10bf9_row17_col0, #T_10bf9_row17_col1, #T_10bf9_row17_col4, #T_10bf9_row18_col0, #T_10bf9_row18_col1, #T_10bf9_row18_col4, #T_10bf9_row19_col0, #T_10bf9_row19_col1, #T_10bf9_row19_col4, #T_10bf9_row20_col0, #T_10bf9_row20_col1, #T_10bf9_row20_col4, #T_10bf9_row21_col0, #T_10bf9_row21_col1, #T_10bf9_row21_col4, #T_10bf9_row22_col0, #T_10bf9_row22_col1, #T_10bf9_row22_col4, #T_10bf9_row23_col0, #T_10bf9_row23_col1, #T_10bf9_row23_col4, #T_10bf9_row24_col0, #T_10bf9_row24_col1, #T_10bf9_row24_col4, #T_10bf9_row25_col0, #T_10bf9_row25_col1, #T_10bf9_row25_col4, #T_10bf9_row26_col0, #T_10bf9_row26_col1, #T_10bf9_row26_col4, #T_10bf9_row27_col0, #T_10bf9_row27_col1, #T_10bf9_row27_col4, #T_10bf9_row28_col0, #T_10bf9_row28_col1, #T_10bf9_row28_col4, #T_10bf9_row29_col0, #T_10bf9_row29_col1, #T_10bf9_row29_col4, #T_10bf9_row30_col0, #T_10bf9_row30_col1, #T_10bf9_row30_col4, #T_10bf9_row31_col0, #T_10bf9_row31_col1, #T_10bf9_row31_col4, #T_10bf9_row32_col0, #T_10bf9_row32_col1, #T_10bf9_row32_col4, #T_10bf9_row33_col0, #T_10bf9_row33_col1, #T_10bf9_row33_col4, #T_10bf9_row34_col0, #T_10bf9_row34_col1, #T_10bf9_row34_col4, #T_10bf9_row35_col0, #T_10bf9_row35_col1, #T_10bf9_row35_col4, #T_10bf9_row36_col0, #T_10bf9_row36_col1, #T_10bf9_row36_col4, #T_10bf9_row37_col0, #T_10bf9_row37_col1, #T_10bf9_row37_col4, #T_10bf9_row38_col0, #T_10bf9_row38_col1, #T_10bf9_row38_col4, #T_10bf9_row39_col0, #T_10bf9_row39_col1, #T_10bf9_row39_col4, #T_10bf9_row40_col0, #T_10bf9_row40_col1, #T_10bf9_row40_col4, #T_10bf9_row41_col0, #T_10bf9_row41_col1, #T_10bf9_row41_col4, #T_10bf9_row42_col0, #T_10bf9_row42_col1, #T_10bf9_row42_col4, #T_10bf9_row43_col0, #T_10bf9_row43_col1, #T_10bf9_row43_col4, #T_10bf9_row44_col0, #T_10bf9_row44_col1, #T_10bf9_row44_col4, #T_10bf9_row45_col0, #T_10bf9_row45_col1, #T_10bf9_row45_col4, #T_10bf9_row46_col0, #T_10bf9_row46_col1, #T_10bf9_row46_col4, #T_10bf9_row47_col0, #T_10bf9_row47_col1, #T_10bf9_row47_col4, #T_10bf9_row48_col0, #T_10bf9_row48_col1, #T_10bf9_row48_col4, #T_10bf9_row49_col0, #T_10bf9_row49_col1, #T_10bf9_row49_col4, #T_10bf9_row50_col0, #T_10bf9_row50_col1, #T_10bf9_row50_col4, #T_10bf9_row51_col0, #T_10bf9_row51_col1, #T_10bf9_row51_col4, #T_10bf9_row52_col0, #T_10bf9_row52_col1, #T_10bf9_row52_col4, #T_10bf9_row53_col0, #T_10bf9_row53_col1, #T_10bf9_row53_col4, #T_10bf9_row54_col0, #T_10bf9_row54_col1, #T_10bf9_row54_col4, #T_10bf9_row55_col0, #T_10bf9_row55_col1, #T_10bf9_row55_col4, #T_10bf9_row56_col0, #T_10bf9_row56_col1, #T_10bf9_row56_col4, #T_10bf9_row57_col0, #T_10bf9_row57_col1, #T_10bf9_row57_col4, #T_10bf9_row58_col0, #T_10bf9_row58_col1, #T_10bf9_row58_col4, #T_10bf9_row59_col0, #T_10bf9_row59_col1, #T_10bf9_row59_col4, #T_10bf9_row60_col0, #T_10bf9_row60_col1, #T_10bf9_row60_col4, #T_10bf9_row61_col0, #T_10bf9_row61_col1, #T_10bf9_row61_col4, #T_10bf9_row62_col0, #T_10bf9_row62_col1, #T_10bf9_row62_col4, #T_10bf9_row63_col0, #T_10bf9_row63_col1, #T_10bf9_row63_col4 ...
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_10bf9_row0_col2 {
#   background-color: #006837;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_10bf9_row0_col3, #T_10bf9_row1_col3, #T_10bf9_row2_col2, #T_10bf9_row2_col3, #T_10bf9_row4_col3, #T_10bf9_row5_col2, #T_10bf9_row5_col3, #T_10bf9_row6_col2, #T_10bf9_row7_col2, #T_10bf9_row7_col3, #T_10bf9_row8_col2, #T_10bf9_row8_col3, #T_10bf9_row9_col2, #T_10bf9_row9_col3, #T_10bf9_row10_col2, #T_10bf9_row10_col3, #T_10bf9_row11_col2, #T_10bf9_row11_col3, #T_10bf9_row12_col3, #T_10bf9_row13_col3, #T_10bf9_row14_col3, #T_10bf9_row15_col2, #T_10bf9_row15_col3, #T_10bf9_row16_col3, #T_10bf9_row17_col3, #T_10bf9_row18_col3, #T_10bf9_row19_col3, #T_10bf9_row20_col3, #T_10bf9_row21_col3, #T_10bf9_row22_col3, #T_10bf9_row23_col3, #T_10bf9_row24_col3, #T_10bf9_row25_col2, #T_10bf9_row27_col2, #T_10bf9_row27_col3, #T_10bf9_row28_col2, #T_10bf9_row28_col3, #T_10bf9_row29_col3, #T_10bf9_row30_col2, #T_10bf9_row31_col2, #T_10bf9_row32_col2, #T_10bf9_row34_col3, #T_10bf9_row36_col3, #T_10bf9_row37_col3, #T_10bf9_row38_col3, #T_10bf9_row39_col3, #T_10bf9_row40_col2, #T_10bf9_row40_col3, #T_10bf9_row41_col2, #T_10bf9_row41_col3, #T_10bf9_row42_col2, #T_10bf9_row42_col3, #T_10bf9_row43_col3, #T_10bf9_row44_col3, #T_10bf9_row45_col3, #T_10bf9_row46_col3, #T_10bf9_row47_col2, #T_10bf9_row47_col3, #T_10bf9_row48_col2, #T_10bf9_row48_col3, #T_10bf9_row49_col2, #T_10bf9_row49_col3, #T_10bf9_row50_col2, #T_10bf9_row50_col3, #T_10bf9_row51_col3, #T_10bf9_row52_col2, #T_10bf9_row52_col3, #T_10bf9_row53_col2, #T_10bf9_row53_col3, #T_10bf9_row54_col3, #T_10bf9_row55_col3, #T_10bf9_row56_col2, #T_10bf9_row56_col3, #T_10bf9_row57_col2, #T_10bf9_row60_col2, #T_10bf9_row61_col2, #T_10bf9_row61_col3, #T_10bf9_row62_col3, #T_10bf9_row63_col2, #T_10bf9_row64_col2, #T_10bf9_row65_col2, #T_10bf9_row65_col3, #T_10bf9_row66_col3, #T_10bf9_row67_col3, #T_10bf9_row68_col3, #T_10bf9_row69_col3, #T_10bf9_row70_col3, #T_10bf9_row71_col3, #T_10bf9_row72_col2, #T_10bf9_row73_col2, #T_10bf9_row74_col2, #T_10bf9_row75_col3, #T_10bf9_row76_col3, #T_10bf9_row77_col2, #T_10bf9_row77_col3, #T_10bf9_row78_col3, #T_10bf9_row79_col3, #T_10bf9_row80_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_10bf9_row1_col2, #T_10bf9_row23_col2, #T_10bf9_row24_col2, #T_10bf9_row54_col2, #T_10bf9_row76_col2 {
#   background-color: #a90426;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_10bf9_row3_col2, #T_10bf9_row19_col2 {
#   background-color: #ca2427;
#   color: #f1f1f1;
#   border: 1px sol
# ## 🔍 Thống Kê Mô Tả
# <style type="text/css">
# #T_c645a th {
#   background-color: #4CAF50;
#   color: white;
#   font-weight: bold;
#   text-align: center;
#   padding: 10px;
# }
# #T_c645a td {
#   text-align: center;
# }
# #T_c645a  {
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_c645a_row0_col0, #T_c645a_row0_col1, #T_c645a_row0_col2, #T_c645a_row0_col3, #T_c645a_row0_col4, #T_c645a_row0_col5, #T_c645a_row0_col6, #T_c645a_row0_col7, #T_c645a_row0_col8, #T_c645a_row0_col9, #T_c645a_row0_col10, #T_c645a_row1_col0, #T_c645a_row1_col1, #T_c645a_row1_col2, #T_c645a_row1_col3, #T_c645a_row1_col4, #T_c645a_row1_col5, #T_c645a_row1_col6, #T_c645a_row1_col7, #T_c645a_row1_col8, #T_c645a_row1_col9, #T_c645a_row1_col10, #T_c645a_row2_col0, #T_c645a_row2_col1, #T_c645a_row2_col2, #T_c645a_row2_col3, #T_c645a_row2_col4, #T_c645a_row2_col5, #T_c645a_row2_col6, #T_c645a_row2_col7, #T_c645a_row2_col8, #T_c645a_row2_col9, #T_c645a_row2_col10, #T_c645a_row3_col0, #T_c645a_row3_col1, #T_c645a_row3_col2, #T_c645a_row3_col3, #T_c645a_row3_col4, #T_c645a_row3_col5, #T_c645a_row3_col6, #T_c645a_row3_col7, #T_c645a_row3_col8, #T_c645a_row3_col9, #T_c645a_row3_col10, #T_c645a_row4_col0, #T_c645a_row4_col1, #T_c645a_row4_col2, #T_c645a_row4_col3, #T_c645a_row4_col4, #T_c645a_row4_col5, #T_c645a_row4_col6, #T_c645a_row4_col7, #T_c645a_row4_col8, #T_c645a_row4_col9, #T_c645a_row4_col10, #T_c645a_row5_col0, #T_c645a_row5_col1, #T_c645a_row5_col2, #T_c645a_row5_col3, #T_c645a_row5_col4, #T_c645a_row5_col5, #T_c645a_row5_col6, #T_c645a_row5_col7, #T_c645a_row5_col8, #T_c645a_row5_col9, #T_c645a_row5_col10, #T_c645a_row6_col0, #T_c645a_row6_col1, #T_c645a_row6_col2, #T_c645a_row6_col3, #T_c645a_row6_col4, #T_c645a_row6_col5, #T_c645a_row6_col6, #T_c645a_row6_col7, #T_c645a_row6_col8, #T_c645a_row6_col9, #T_c645a_row6_col10, #T_c645a_row7_col0, #T_c645a_row7_col1, #T_c645a_row7_col2, #T_c645a_row7_col3, #T_c645a_row7_col4, #T_c645a_row7_col5, #T_c645a_row7_col6, #T_c645a_row7_col7, #T_c645a_row7_col8, #T_c645a_row7_col9, #T_c645a_row7_col10, #T_c645a_row8_col0, #T_c645a_row8_col1, #T_c645a_row8_col2, #T_c645a_row8_col3, #T_c645a_row8_col4, #T_c645a_row8_col5, #T_c645a_row8_col6, #T_c645a_row8_col7, #T_c645a_row8_col8, #T_c645a_row8_col9, #T_c645a_row8_col10, #T_c645a_row9_col0, #T_c645a_row9_col1, #T_c645a_row9_col2, #T_c645a_row9_col3, #T_c645a_row9_col4, #T_c645a_row9_col5, #T_c645a_row9_col6, #T_c645a_row9_col7, #T_c645a_row9_col8, #T_c645a_row9_col9, #T_c645a_row9_col10, #T_c645a_row10_col0, #T_c645a_row10_col1, #T_c645a_row10_col2, #T_c645a_row10_col3, #T_c645a_row10_col4, #T_c645a_row10_col5, #T_c645a_row10_col6, #T_c645a_row10_col7, #T_c645a_row10_col8, #T_c645a_row10_col9, #T_c645a_row10_col10, #T_c645a_row11_col0, #T_c645a_row11_col1, #T_c645a_row11_col2, #T_c645a_row11_col3, #T_c645a_row11_col4, #T_c645a_row11_col5, #T_c645a_row11_col6, #T_c645a_row11_col7, #T_c645a_row11_col8, #T_c645a_row11_col9, #T_c645a_row11_col10, #T_c645a_row12_col0, #T_c645a_row12_col1, #T_c645a_row12_col2, #T_c645a_row12_col3, #T_c645a_row12_col4, #T_c645a_row12_col5, #T_c645a_row12_col6, #T_c645a_row12_col7, #T_c645a_row12_col8, #T_c645a_row12_col9, #T_c645a_row12_col10, #T_c645a_row13_col0, #T_c645a_row13_col1, #T_c645a_row13_col2, #T_c645a_row13_col3, #T_c645a_row13_col4, #T_c645a_row13_col5, #T_c645a_row13_col6, #T_c645a_row13_col7, #T_c645a_row13_col8, #T_c645a_row13_col9, #T_c645a_row13_col10, #T_c645a_row14_col0, #T_c645a_row14_col1, #T_c645a_row14_col2, #T_c645a_row14_col3, #T_c645a_row14_col4, #T_c645a_row14_col5, #T_c645a_row14_col6, #T_c645a_row14_col7, #T_c645a_row14_col8, #T_c645a_row14_col9, #T_c645a_row14_col10, #T_c645a_row15_col0, #T_c645a_row15_col1, #T_c645a_row15_col2, #T_c645a_row15_col3, #T_c645a_row15_col4, #T_c645a_row15_col5, #T_c645a_row15_col6, #T_c645a_row15_col7, #T_c645a_row15_col8, #T_c645a_row15_col9, #T_c645a_row15_col10, #T_c645a_row16_col0, #T_c645a_row16_col1, #T_c645a_row16_col2, #T_c645a_row16_col3, #T_c645a_row16_col4, #T_c645a_row16_col5, #T_c645a_row16_col6, #T_c645a_row16_col7, #T_c645a_row16_col8, #T_c645a_row16_col9, #T_c645a_row16_col10, #T_c645a_row17_col0, #T_c645a_row17_col1, #T_c645a_row17_col2, #T_c645a_row17_col3, #T_c645a_row17_col4, #T_c645a_row17_col5, #T_c645a_row17_col6, #T_c645a_row17_col7 ...

# %% [markdown]
# ## 📉 Demo 2: Phân Tích Giá Trị Thiếu (Missing Values)
#
# Kiểm tra các cột có giá trị thiếu và biểu đồ trực quan.

# %%
# Phân tích giá trị thiếu cho train dataset
eda_train.missing_values()
# Out:
# ## 🔍 Phân Tích Giá Trị Thiếu
# **📉 Các cột có giá trị thiếu**
# <style type="text/css">
# #T_e14ff th {
#   background-color: #4CAF50;
#   color: white;
#   font-weight: bold;
#   text-align: center;
#   padding: 10px;
# }
# #T_e14ff td {
#   text-align: center;
# }
# #T_e14ff  {
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_e14ff_row0_col0, #T_e14ff_row1_col0, #T_e14ff_row2_col0, #T_e14ff_row3_col0, #T_e14ff_row4_col0, #T_e14ff_row5_col0, #T_e14ff_row6_col0, #T_e14ff_row7_col0, #T_e14ff_row8_col0, #T_e14ff_row9_col0, #T_e14ff_row10_col0, #T_e14ff_row11_col0, #T_e14ff_row12_col0, #T_e14ff_row13_col0, #T_e14ff_row14_col0, #T_e14ff_row15_col0, #T_e14ff_row16_col0, #T_e14ff_row17_col0, #T_e14ff_row18_col0 {
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_e14ff_row0_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_e14ff_row0_col2 {
#   background-color: #c62027;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_e14ff_row1_col1 {
#   background-color: #08773f;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_e14ff_row1_col2, #T_e14ff_row2_col2 {
#   background-color: #c41e27;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_e14ff_row2_col1 {
#   background-color: #0e8245;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_e14ff_row3_col1 {
#   background-color: #5db961;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_e14ff_row3_col2, #T_e14ff_row7_col1, #T_e14ff_row8_col1, #T_e14ff_row9_col1, #T_e14ff_row10_col1, #T_e14ff_row11_col1 {
#   background-color: #c01a27;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_e14ff_row4_col1 {
#   background-color: #d9ef8b;
#   color: #000000;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_e14ff_row4_col2 {
#   background-color: #b91326;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_e14ff_row5_col1 {
#   background-color: #fff7b2;
#   color: #000000;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_e14ff_row5_col2 {
#   background-color: #b50f26;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_e14ff_row6_col1 {
#   background-color: #ed5f3c;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_e14ff_row6_col2 {
#   background-color: #ab0626;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_e14ff_row7_col2, #T_e14ff_row8_col2, #T_e14ff_row9_col2, #T_e14ff_row10_col2, #T_e14ff_row11_col2, #T_e14ff_row12_col2, #T_e14ff_row13_col2, #T_e14ff_row14_col2, #T_e14ff_row15_col2, #T_e14ff_row16_col2, #T_e14ff_row17_col2, #T_e14ff_row18_col1, #T_e14ff_row18_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_e14ff_row12_col1, #T_e14ff_row13_col1, #T_e14ff_row14_col1, #T_e14ff_row15_col1, #T_e14ff_row16_col1 {
#   background-color: #b10b26;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_e14ff_row17_col1 {
#   background-color: #a70226;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# </style>
# <table id="T_e14ff">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e14ff_level0_col0" class="col_heading level0 col0" >Cột</th>
#       <th id="T_e14ff_level0_col1" class="col_heading level0 col1" >Số lượng thiếu</th>
#       <th id="T_e14ff_level0_col2" class="col_heading level0 col2" >% thiếu</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e14ff_level0_row0" class="row_heading level0 row0" >72</th>
#       <td id="T_e14ff_row0_col0" class="data row0 col0" >PoolQC</td>
#       <td id="T_e14ff_row0_col1" class="data row0 col1" >1453</td>
#       <td id="T_e14ff_row0_col2" class="data row0 col2" >99.520000</td>
#     </tr>
#     <tr>
#       <th id="T_e14ff_level0_row1" class="row_heading level0 row1" >74</th>
#       <td id="T_e14ff_row1_col0" class="data row1 col0" >MiscFeature</td>
#       <td id="T_e14ff_row1_col1" class="data row1 col1" >1406</td>
#       <td id="T_e14ff_row1_col2" class="data row1 col2" >96.300000</td>
#     </tr>
#     <tr>
#       <th id="T_e14ff_level0_row2" class="row_heading level0 row2" >6</th>
#       <td id="T_e14ff_row2_col0" class="data row2 col0" >Alley</td>
#       <td id="T_e14ff_row2_col1" class="data row2 col1" >1369</td>
#       <td id="T_e14ff_row2_col2" class="data row2 col2" >93.770000</td>
#     </tr>
#     <tr>
#       <th id="T_e14ff_level0_row3" class="row_heading level0 row3" >73</th>
#       <td id="T_e14ff_row3_col0" class="data row3 col0" >Fence</td>
#       <td id="T_e14ff_row3_col1" class="data row3 col1" >1179</td>
#       <td id="T_e14ff_row3_col2" class="data row3 col2" >80.750000</td>
#     </tr>
#     <tr>
#       <th id="T_e14ff_level0_row4" class="row_heading level0 row4" >25</th>
#       <td id="T_e14ff_row4_col0" class="data row4 col0" >MasVnrType</td>
#       <td id="T_e14ff_row4_col1" class="data row4 col1" >872</td>
#       <td id="T_e14ff_row4_col2" class="data row4 col2" >59.730000</td>
#     </tr>
#     <tr>
#       <th id="T_e14ff_level0_row5" class="row_heading level0 row5" >57</th>
#       <td id="T_e14ff_row5_col0" class="data row5 col0" >FireplaceQu</td>
#       <td id="T_e14ff_row5_col1" class="data row5 col1" >690</td>
#       <td id="T_e14ff_row5_col2" class="data row5 col2" >47.260000</td>
#     </tr>
#     <tr>
#       <th id="T_e14ff_level0_row6" class="row_heading level0 row6" >3</th>
#       <td id="T_e14ff_row6_col0" class="data row6 col0" >LotFrontage</td>
#       <td id="T_e14ff_row6_col1" class="data row6 col1" >259</td>
#       <td id="T_e14ff_row6_col2" class="data row6 col2" >17.740000</td>
#     </tr>
#     <tr>
#       <th id="T_e14ff_level0_row7" class="row_heading level0 row7" >58</th>
#       <td id="T_e14ff_row7_col0" class="data row7 col0" >GarageType</td>
#       <td id="T_e14ff_row7_col1" class="data row7 col1" >81</td>
#       <td id="T_e14ff_row7_col2" class="data row7 col2" >5.550000</td>
#     </tr>
#     <tr>
#       <th id="T_e14ff_level0_row8" class="row_heading level0 row8" >59</th>
#       <td id="T_e14ff_row8_col0" class="data row8 col0" >GarageYrBlt</td>
#       <td id="T_e14ff_row8_col1" class="data row8 col1" >81</td>
#       <td id="T_e14ff_row8_col2" class="data row8 col2" >5.550000</td>
#     </tr>
#     <tr>
#       <th id="T_e14ff_level0_row9" class="row_heading level0 row9" >60</th>
#       <td id="T_e14ff_row9_col0" class="data row9 col0" >GarageFinish</td>
#       <td id="T_e14ff_row9_col1" class="data row9 col1" >81</td>
#       <td id="T_e14ff_row9_col2" class="data row9 col2" >5.550000</td>
#     </tr>
#     <tr>
#       <th id="T_e14ff_level0_row10" class="row_heading level0 row10" >63</th>
#       <td id="T_e14ff_row10_col0" class="data row10 col0" >GarageQual</td>
#       <td id="T_e14ff_row10_col1" class="data row10 col1" >81</td>
#       <td id="T_e14ff_row10_col2" class="data row10 col2" >5.550000</td>
#     </tr>
#     <tr>
#       <th id="T_e14ff_level0_row11" class="row_heading level0 row11" >64</th>
#       <td id="T_e14ff_row11_col0" class="data row11 col0" >GarageCond</td>
#       <td id="T_e14ff_row11_col1" class="data row11 col1" >81</td>
#       <td id="T_e14ff_row11_col2" class="data row11 col2" >5.550000</td>
#     </tr>
#     <tr>
#       <th id="T_e14ff_level0_row12" class="row_heading level0 row12" >32</th>
#       <td id="T_e14ff_row12_col0" class="data row12 col0" >BsmtExposure</td>
#       <td id="T_e14ff_row12_col1" class="data row12 col1" >38</td>
#       <td id="T_e14ff_row12_col2" class="data row12 col2" >2.600000</td>
#     </tr>
#     <tr>
#       <th id="T_e14ff_level0_row13" class="row_heading level0 row13" >35</th>
#       <td id="T_e14ff_row13_col0" class="data row13 col0" >BsmtFinType2</td>
#       <td id="T_e14ff_row13_col1" class="data row13 col1" >38</td>
#       <td id="T_e14ff_row13_col2" class="data row13 col2" >2.600000</td>
#     </tr>
#     <tr>
#       <th id="T_e14

# %% [markdown]
# ## 📊 Demo 3: Phân Bố Biến Số (Distribution)
#
# Xem phân bố của một số biến quan trọng như `SalePrice`, `GrLivArea`, `OverallQual`.

# %%
# Phân bố của SalePrice (biến mục tiêu)
eda_train.distribution('SalePrice', interactive=True)
# Out:
# ### ✨ Phân Bố: SalePrice
# **📊 Thống kê SalePrice**
# <style type="text/css">
# #T_d31e6 th {
#   background-color: #4CAF50;
#   color: white;
#   font-weight: bold;
#   text-align: center;
#   padding: 10px;
# }
# #T_d31e6 td {
#   text-align: center;
# }
# #T_d31e6  {
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_d31e6_row0_col0 {
#   background-color: #f8864f;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_d31e6_row0_col1 {
#   background-color: #f57748;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_d31e6_row0_col2 {
#   background-color: #d83128;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_d31e6_row0_col3 {
#   background-color: #bb1526;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_d31e6_row0_col4 {
#   background-color: #006837;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_d31e6_row0_col5 {
#   background-color: #a50026;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# </style>
# <table id="T_d31e6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d31e6_level0_col0" class="col_heading level0 col0" >Mean</th>
#       <th id="T_d31e6_level0_col1" class="col_heading level0 col1" >Median</th>
#       <th id="T_d31e6_level0_col2" class="col_heading level0 col2" >Std</th>
#       <th id="T_d31e6_level0_col3" class="col_heading level0 col3" >Min</th>
#       <th id="T_d31e6_level0_col4" class="col_heading level0 col4" >Max</th>
#       <th id="T_d31e6_level0_col5" class="col_heading level0 col5" >Skewness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d31e6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d31e6_row0_col0" class="data row0 col0" >180921.195890</td>
#       <td id="T_d31e6_row0_col1" class="data row0 col1" >163000.000000</td>
#       <td id="T_d31e6_row0_col2" class="data row0 col2" >79442.502883</td>
#       <td id="T_d31e6_row0_col3" class="data row0 col3" >34900</td>
#       <td id="T_d31e6_row0_col4" class="data row0 col4" >755000</td>
#       <td id="T_d31e6_row0_col5" class="data row0 col5" >1.882876</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Phân bố của GrLivArea (diện tích sống)
eda_train.distribution('GrLivArea', interactive=True)
# Out:
# ### ✨ Phân Bố: GrLivArea
# **📊 Thống kê GrLivArea**
# <style type="text/css">
# #T_2e120 th {
#   background-color: #4CAF50;
#   color: white;
#   font-weight: bold;
#   text-align: center;
#   padding: 10px;
# }
# #T_2e120 td {
#   text-align: center;
# }
# #T_2e120  {
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_2e120_row0_col0 {
#   background-color: #fa9857;
#   color: #000000;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_2e120_row0_col1 {
#   background-color: #f99355;
#   color: #000000;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_2e120_row0_col2 {
#   background-color: #d22b27;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_2e120_row0_col3 {
#   background-color: #c21c27;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_2e120_row0_col4 {
#   background-color: #006837;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_2e120_row0_col5 {
#   background-color: #a50026;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# </style>
# <table id="T_2e120">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2e120_level0_col0" class="col_heading level0 col0" >Mean</th>
#       <th id="T_2e120_level0_col1" class="col_heading level0 col1" >Median</th>
#       <th id="T_2e120_level0_col2" class="col_heading level0 col2" >Std</th>
#       <th id="T_2e120_level0_col3" class="col_heading level0 col3" >Min</th>
#       <th id="T_2e120_level0_col4" class="col_heading level0 col4" >Max</th>
#       <th id="T_2e120_level0_col5" class="col_heading level0 col5" >Skewness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2e120_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2e120_row0_col0" class="data row0 col0" >1515.463699</td>
#       <td id="T_2e120_row0_col1" class="data row0 col1" >1464.000000</td>
#       <td id="T_2e120_row0_col2" class="data row0 col2" >525.480383</td>
#       <td id="T_2e120_row0_col3" class="data row0 col3" >334</td>
#       <td id="T_2e120_row0_col4" class="data row0 col4" >5642</td>
#       <td id="T_2e120_row0_col5" class="data row0 col5" >1.366560</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Phân bố của OverallQual (chất lượng tổng thể)
eda_train.distribution('OverallQual', interactive=True)
# Out:
# ### ✨ Phân Bố: OverallQual
# **📊 Thống kê OverallQual**
# <style type="text/css">
# #T_eec62 th {
#   background-color: #4CAF50;
#   color: white;
#   font-weight: bold;
#   text-align: center;
#   padding: 10px;
# }
# #T_eec62 td {
#   text-align: center;
# }
# #T_eec62  {
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_eec62_row0_col0 {
#   background-color: #d9ef8b;
#   color: #000000;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_eec62_row0_col1 {
#   background-color: #dcf08f;
#   color: #000000;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_eec62_row0_col2 {
#   background-color: #dc3b2c;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_eec62_row0_col3 {
#   background-color: #cc2627;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_eec62_row0_col4 {
#   background-color: #006837;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_eec62_row0_col5 {
#   background-color: #a50026;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# </style>
# <table id="T_eec62">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eec62_level0_col0" class="col_heading level0 col0" >Mean</th>
#       <th id="T_eec62_level0_col1" class="col_heading level0 col1" >Median</th>
#       <th id="T_eec62_level0_col2" class="col_heading level0 col2" >Std</th>
#       <th id="T_eec62_level0_col3" class="col_heading level0 col3" >Min</th>
#       <th id="T_eec62_level0_col4" class="col_heading level0 col4" >Max</th>
#       <th id="T_eec62_level0_col5" class="col_heading level0 col5" >Skewness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eec62_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_eec62_row0_col0" class="data row0 col0" >6.099315</td>
#       <td id="T_eec62_row0_col1" class="data row0 col1" >6.000000</td>
#       <td id="T_eec62_row0_col2" class="data row0 col2" >1.382997</td>
#       <td id="T_eec62_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_eec62_row0_col4" class="data row0 col4" >10</td>
#       <td id="T_eec62_row0_col5" class="data row0 col5" >0.216944</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 🔥 Demo 4: Ma Trận Tương Quan (Correlation Matrix)
#
# Xem mối tương quan giữa các biến số.

# %%
# Ma trận tương quan interactive
eda_train.correlation_matrix(interactive=True)
# Out:
# ## 🔍 Ma Trận Tương Quan

# %% [markdown]
# ## 📝 Demo 5: Phân Tích Biến Phân Loại (Categorical Variables)
#
# Xem phân bố của các biến phân loại như `Neighborhood`, `HouseStyle`, `SaleCondition`.

# %%
# Phân tích biến Neighborhood
eda_train.categorical_summary('Neighborhood', top_n=10)
# Out:
# ### ✨ Phân Tích: Neighborhood
# **📋 Bảng tần suất Neighborhood**
# <style type="text/css">
# #T_d49a2 th {
#   background-color: #4CAF50;
#   color: white;
#   font-weight: bold;
#   text-align: center;
#   padding: 10px;
# }
# #T_d49a2 td {
#   text-align: center;
# }
# #T_d49a2  {
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_d49a2_row0_col0, #T_d49a2_row1_col0, #T_d49a2_row2_col0, #T_d49a2_row3_col0, #T_d49a2_row4_col0, #T_d49a2_row5_col0, #T_d49a2_row6_col0, #T_d49a2_row7_col0, #T_d49a2_row8_col0, #T_d49a2_row9_col0 {
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_d49a2_row0_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_d49a2_row0_col2 {
#   background-color: #be1827;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_d49a2_row1_col1 {
#   background-color: #b9e176;
#   color: #000000;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_d49a2_row1_col2 {
#   background-color: #b30d26;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_d49a2_row2_col1 {
#   background-color: #fffdbc;
#   color: #000000;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_d49a2_row2_col2 {
#   background-color: #ad0826;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_d49a2_row3_col1 {
#   background-color: #feeb9d;
#   color: #000000;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_d49a2_row3_col2 {
#   background-color: #ab0626;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_d49a2_row4_col1 {
#   background-color: #fed07e;
#   color: #000000;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_d49a2_row4_col2 {
#   background-color: #a90426;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_d49a2_row5_col1 {
#   background-color: #fdc171;
#   color: #000000;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_d49a2_row5_col2, #T_d49a2_row6_col2, #T_d49a2_row7_col2, #T_d49a2_row8_col2 {
#   background-color: #a70226;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_d49a2_row6_col1 {
#   background-color: #fdbd6d;
#   color: #000000;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_d49a2_row7_col1 {
#   background-color: #fdb768;
#   color: #000000;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_d49a2_row8_col1 {
#   background-color: #fdb365;
#   color: #000000;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_d49a2_row9_col1 {
#   background-color: #f88c51;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_d49a2_row9_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# </style>
# <table id="T_d49a2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d49a2_level0_col0" class="col_heading level0 col0" >Giá trị</th>
#       <th id="T_d49a2_level0_col1" class="col_heading level0 col1" >Số lượng</th>
#       <th id="T_d49a2_level0_col2" class="col_heading level0 col2" >Tỷ lệ %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d49a2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d49a2_row0_col0" class="data row0 col0" >NAmes</td>
#       <td id="T_d49a2_row0_col1" class="data row0 col1" >225</td>
#       <td id="T_d49a2_row0_col2" class="data row0 col2" >15.410000</td>
#     </tr>
#     <tr>
#       <th id="T_d49a2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d49a2_row1_col0" class="data row1 col0" >CollgCr</td>
#       <td id="T_d49a2_row1_col1" class="data row1 col1" >150</td>
#       <td id="T_d49a2_row1_col2" class="data row1 col2" >10.270000</td>
#     </tr>
#     <tr>
#       <th id="T_d49a2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d49a2_row2_col0" class="data row2 col0" >OldTown</td>
#       <td id="T_d49a2_row2_col1" class="data row2 col1" >113</td>
#       <td id="T_d49a2_row2_col2" class="data row2 col2" >7.740000</td>
#     </tr>
#     <tr>
#       <th id="T_d49a2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d49a2_row3_col0" class="data row3 col0" >Edwards</td>
#       <td id="T_d49a2_row3_col1" class="data row3 col1" >100</td>
#       <td id="T_d49a2_row3_col2" class="data row3 col2" >6.850000</td>
#     </tr>
#     <tr>
#       <th id="T_d49a2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d49a2_row4_col0" class="data row4 col0" >Somerst</td>
#       <td id="T_d49a2_row4_col1" class="data row4 col1" >86</td>
#       <td id="T_d49a2_row4_col2" class="data row4 col2" >5.890000</td>
#     </tr>
#     <tr>
#       <th id="T_d49a2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d49a2_row5_col0" class="data row5 col0" >Gilbert</td>
#       <td id="T_d49a2_row5_col1" class="data row5 col1" >79</td>
#       <td id="T_d49a2_row5_col2" class="data row5 col2" >5.410000</td>
#     </tr>
#     <tr>
#       <th id="T_d49a2_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d49a2_row6_col0" class="data row6 col0" >NridgHt</td>
#       <td id="T_d49a2_row6_col1" class="data row6 col1" >77</td>
#       <td id="T_d49a2_row6_col2" class="data row6 col2" >5.270000</td>
#     </tr>
#     <tr>
#       <th id="T_d49a2_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d49a2_row7_col0" class="data row7 col0" >Sawyer</td>
#       <td id="T_d49a2_row7_col1" class="data row7 col1" >74</td>
#       <td id="T_d49a2_row7_col2" class="data row7 col2" >5.070000</td>
#     </tr>
#     <tr>
#       <th id="T_d49a2_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d49a2_row8_col0" class="data row8 col0" >NWAmes</td>
#       <td id="T_d49a2_row8_col1" class="data row8 col1" >73</td>
#       <td id="T_d49a2_row8_col2" class="data row8 col2" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d49a2_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d49a2_row9_col0" class="data row9 col0" >SawyerW</td>
#       <td id="T_d49a2_row9_col1" class="data row9 col1" >59</td>
#       <td id="T_d49a2_row9_col2" class="data row9 col2" >4.040000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Phân tích biến HouseStyle
eda_train.categorical_summary('HouseStyle', top_n=10)
# Out:
# ### ✨ Phân Tích: HouseStyle
# **📋 Bảng tần suất HouseStyle**
# <style type="text/css">
# #T_a0e05 th {
#   background-color: #4CAF50;
#   color: white;
#   font-weight: bold;
#   text-align: center;
#   padding: 10px;
# }
# #T_a0e05 td {
#   text-align: center;
# }
# #T_a0e05  {
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_a0e05_row0_col0, #T_a0e05_row1_col0, #T_a0e05_row2_col0, #T_a0e05_row3_col0, #T_a0e05_row4_col0, #T_a0e05_row5_col0, #T_a0e05_row6_col0, #T_a0e05_row7_col0 {
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_a0e05_row0_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_a0e05_row0_col2 {
#   background-color: #c62027;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_a0e05_row1_col1 {
#   background-color: #d3ec87;
#   color: #000000;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_a0e05_row1_col2 {
#   background-color: #b91326;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_a0e05_row2_col1 {
#   background-color: #f57547;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_a0e05_row2_col2, #T_a0e05_row6_col1 {
#   background-color: #ab0626;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_a0e05_row3_col1 {
#   background-color: #d02927;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_a0e05_row3_col2 {
#   background-color: #a70226;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_a0e05_row4_col1 {
#   background-color: #bd1726;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_a0e05_row4_col2, #T_a0e05_row5_col2, #T_a0e05_row6_col2, #T_a0e05_row7_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_a0e05_row5_col1 {
#   background-color: #ad0826;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_a0e05_row7_col1 {
#   background-color: #a90426;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# </style>
# <table id="T_a0e05">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a0e05_level0_col0" class="col_heading level0 col0" >Giá trị</th>
#       <th id="T_a0e05_level0_col1" class="col_heading level0 col1" >Số lượng</th>
#       <th id="T_a0e05_level0_col2" class="col_heading level0 col2" >Tỷ lệ %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a0e05_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a0e05_row0_col0" class="data row0 col0" >1Story</td>
#       <td id="T_a0e05_row0_col1" class="data row0 col1" >726</td>
#       <td id="T_a0e05_row0_col2" class="data row0 col2" >49.730000</td>
#     </tr>
#     <tr>
#       <th id="T_a0e05_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a0e05_row1_col0" class="data row1 col0" >2Story</td>
#       <td id="T_a0e05_row1_col1" class="data row1 col1" >445</td>
#       <td id="T_a0e05_row1_col2" class="data row1 col2" >30.480000</td>
#     </tr>
#     <tr>
#       <th id="T_a0e05_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a0e05_row2_col0" class="data row2 col0" >1.5Fin</td>
#       <td id="T_a0e05_row2_col1" class="data row2 col1" >154</td>
#       <td id="T_a0e05_row2_col2" class="data row2 col2" >10.550000</td>
#     </tr>
#     <tr>
#       <th id="T_a0e05_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a0e05_row3_col0" class="data row3 col0" >SLvl</td>
#       <td id="T_a0e05_row3_col1" class="data row3 col1" >65</td>
#       <td id="T_a0e05_row3_col2" class="data row3 col2" >4.450000</td>
#     </tr>
#     <tr>
#       <th id="T_a0e05_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a0e05_row4_col0" class="data row4 col0" >SFoyer</td>
#       <td id="T_a0e05_row4_col1" class="data row4 col1" >37</td>
#       <td id="T_a0e05_row4_col2" class="data row4 col2" >2.530000</td>
#     </tr>
#     <tr>
#       <th id="T_a0e05_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a0e05_row5_col0" class="data row5 col0" >1.5Unf</td>
#       <td id="T_a0e05_row5_col1" class="data row5 col1" >14</td>
#       <td id="T_a0e05_row5_col2" class="data row5 col2" >0.960000</td>
#     </tr>
#     <tr>
#       <th id="T_a0e05_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a0e05_row6_col0" class="data row6 col0" >2.5Unf</td>
#       <td id="T_a0e05_row6_col1" class="data row6 col1" >11</td>
#       <td id="T_a0e05_row6_col2" class="data row6 col2" >0.750000</td>
#     </tr>
#     <tr>
#       <th id="T_a0e05_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a0e05_row7_col0" class="data row7 col0" >2.5Fin</td>
#       <td id="T_a0e05_row7_col1" class="data row7 col1" >8</td>
#       <td id="T_a0e05_row7_col2" class="data row7 col2" >0.550000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Phân tích biến SaleCondition
eda_train.categorical_summary('SaleCondition', top_n=10)
# Out:
# ### ✨ Phân Tích: SaleCondition
# **📋 Bảng tần suất SaleCondition**
# <style type="text/css">
# #T_90aff th {
#   background-color: #4CAF50;
#   color: white;
#   font-weight: bold;
#   text-align: center;
#   padding: 10px;
# }
# #T_90aff td {
#   text-align: center;
# }
# #T_90aff  {
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_90aff_row0_col0, #T_90aff_row1_col0, #T_90aff_row2_col0, #T_90aff_row3_col0, #T_90aff_row4_col0, #T_90aff_row5_col0 {
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_90aff_row0_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_90aff_row0_col2 {
#   background-color: #c62027;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_90aff_row1_col1 {
#   background-color: #d83128;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_90aff_row1_col2, #T_90aff_row2_col2 {
#   background-color: #a70226;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_90aff_row2_col1 {
#   background-color: #ce2827;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_90aff_row3_col1 {
#   background-color: #ad0826;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_90aff_row3_col2, #T_90aff_row4_col2, #T_90aff_row5_col1, #T_90aff_row5_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_90aff_row4_col1 {
#   background-color: #a90426;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# </style>
# <table id="T_90aff">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_90aff_level0_col0" class="col_heading level0 col0" >Giá trị</th>
#       <th id="T_90aff_level0_col1" class="col_heading level0 col1" >Số lượng</th>
#       <th id="T_90aff_level0_col2" class="col_heading level0 col2" >Tỷ lệ %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_90aff_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_90aff_row0_col0" class="data row0 col0" >Normal</td>
#       <td id="T_90aff_row0_col1" class="data row0 col1" >1198</td>
#       <td id="T_90aff_row0_col2" class="data row0 col2" >82.050000</td>
#     </tr>
#     <tr>
#       <th id="T_90aff_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_90aff_row1_col0" class="data row1 col0" >Partial</td>
#       <td id="T_90aff_row1_col1" class="data row1 col1" >125</td>
#       <td id="T_90aff_row1_col2" class="data row1 col2" >8.560000</td>
#     </tr>
#     <tr>
#       <th id="T_90aff_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_90aff_row2_col0" class="data row2 col0" >Abnorml</td>
#       <td id="T_90aff_row2_col1" class="data row2 col1" >101</td>
#       <td id="T_90aff_row2_col2" class="data row2 col2" >6.920000</td>
#     </tr>
#     <tr>
#       <th id="T_90aff_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_90aff_row3_col0" class="data row3 col0" >Family</td>
#       <td id="T_90aff_row3_col1" class="data row3 col1" >20</td>
#       <td id="T_90aff_row3_col2" class="data row3 col2" >1.370000</td>
#     </tr>
#     <tr>
#       <th id="T_90aff_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_90aff_row4_col0" class="data row4 col0" >Alloca</td>
#       <td id="T_90aff_row4_col1" class="data row4 col1" >12</td>
#       <td id="T_90aff_row4_col2" class="data row4 col2" >0.820000</td>
#     </tr>
#     <tr>
#       <th id="T_90aff_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_90aff_row5_col0" class="data row5 col0" >AdjLand</td>
#       <td id="T_90aff_row5_col1" class="data row5 col1" >4</td>
#       <td id="T_90aff_row5_col2" class="data row5 col2" >0.270000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 🎯 Demo 6: Phát Hiện Ngoại Lai (Outlier Detection)
#
# Phát hiện các giá trị ngoại lai trong dữ liệu.

# %%
# Phát hiện ngoại lai cho SalePrice
outliers_price = eda_train.outlier_detection('SalePrice')
print(f"\n🔍 Số lượng ngoại lai: {len(outliers_price)}")
# Out:
# ### ✨ Phát Hiện Ngoại Lai: SalePrice
# **🎯 Thông tin ngoại lai**
# <style type="text/css">
# #T_98e4f th {
#   background-color: #4CAF50;
#   color: white;
#   font-weight: bold;
#   text-align: center;
#   padding: 10px;
# }
# #T_98e4f td {
#   text-align: center;
# }
# #T_98e4f  {
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_98e4f_row0_col0 {
#   background-color: #a70226;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_98e4f_row0_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_98e4f_row0_col2 {
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_98e4f_row0_col3 {
#   background-color: #fed683;
#   color: #000000;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_98e4f_row0_col4 {
#   background-color: #c9e881;
#   color: #000000;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_98e4f_row0_col5 {
#   background-color: #f88c51;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_98e4f_row0_col6 {
#   background-color: #a90426;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_98e4f_row0_col7 {
#   background-color: #006837;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# </style>
# <table id="T_98e4f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_98e4f_level0_col0" class="col_heading level0 col0" >Tổng số điểm</th>
#       <th id="T_98e4f_level0_col1" class="col_heading level0 col1" >Số ngoại lai</th>
#       <th id="T_98e4f_level0_col2" class="col_heading level0 col2" >% ngoại lai</th>
#       <th id="T_98e4f_level0_col3" class="col_heading level0 col3" >Q1</th>
#       <th id="T_98e4f_level0_col4" class="col_heading level0 col4" >Q3</th>
#       <th id="T_98e4f_level0_col5" class="col_heading level0 col5" >IQR</th>
#       <th id="T_98e4f_level0_col6" class="col_heading level0 col6" >Lower Bound</th>
#       <th id="T_98e4f_level0_col7" class="col_heading level0 col7" >Upper Bound</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_98e4f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_98e4f_row0_col0" class="data row0 col0" >1460</td>
#       <td id="T_98e4f_row0_col1" class="data row0 col1" >61</td>
#       <td id="T_98e4f_row0_col2" class="data row0 col2" >4.18%</td>
#       <td id="T_98e4f_row0_col3" class="data row0 col3" >129975.000000</td>
#       <td id="T_98e4f_row0_col4" class="data row0 col4" >214000.000000</td>
#       <td id="T_98e4f_row0_col5" class="data row0 col5" >84025.000000</td>
#       <td id="T_98e4f_row0_col6" class="data row0 col6" >3937.500000</td>
#       <td id="T_98e4f_row0_col7" class="data row0 col7" >340037.500000</td>
#     </tr>
#   </tbody>
# </table>
# 🔍 Số lượng ngoại lai: 61

# %%
# Phát hiện ngoại lai cho GrLivArea
outliers_area = eda_train.outlier_detection('GrLivArea')
print(f"\n🔍 Số lượng ngoại lai: {len(outliers_area)}")
# Out:
# ### ✨ Phát Hiện Ngoại Lai: GrLivArea
# **🎯 Thông tin ngoại lai**
# <style type="text/css">
# #T_59f85 th {
#   background-color: #4CAF50;
#   color: white;
#   font-weight: bold;
#   text-align: center;
#   padding: 10px;
# }
# #T_59f85 td {
#   text-align: center;
# }
# #T_59f85  {
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_59f85_row0_col0 {
#   background-color: #f5fbb2;
#   color: #000000;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_59f85_row0_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_59f85_row0_col2 {
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_59f85_row0_col3 {
#   background-color: #fee18d;
#   color: #000000;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_59f85_row0_col4 {
#   background-color: #c3e67d;
#   color: #000000;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_59f85_row0_col5 {
#   background-color: #f67f4b;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_59f85_row0_col6 {
#   background-color: #bd1726;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_59f85_row0_col7 {
#   background-color: #006837;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# </style>
# <table id="T_59f85">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_59f85_level0_col0" class="col_heading level0 col0" >Tổng số điểm</th>
#       <th id="T_59f85_level0_col1" class="col_heading level0 col1" >Số ngoại lai</th>
#       <th id="T_59f85_level0_col2" class="col_heading level0 col2" >% ngoại lai</th>
#       <th id="T_59f85_level0_col3" class="col_heading level0 col3" >Q1</th>
#       <th id="T_59f85_level0_col4" class="col_heading level0 col4" >Q3</th>
#       <th id="T_59f85_level0_col5" class="col_heading level0 col5" >IQR</th>
#       <th id="T_59f85_level0_col6" class="col_heading level0 col6" >Lower Bound</th>
#       <th id="T_59f85_level0_col7" class="col_heading level0 col7" >Upper Bound</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_59f85_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_59f85_row0_col0" class="data row0 col0" >1460</td>
#       <td id="T_59f85_row0_col1" class="data row0 col1" >31</td>
#       <td id="T_59f85_row0_col2" class="data row0 col2" >2.12%</td>
#       <td id="T_59f85_row0_col3" class="data row0 col3" >1129.500000</td>
#       <td id="T_59f85_row0_col4" class="data row0 col4" >1776.750000</td>
#       <td id="T_59f85_row0_col5" class="data row0 col5" >647.250000</td>
#       <td id="T_59f85_row0_col6" class="data row0 col6" >158.625000</td>
#       <td id="T_59f85_row0_col7" class="data row0 col7" >2747.625000</td>
#     </tr>
#   </tbody>
# </table>
# 🔍 Số lượng ngoại lai: 31

# %% [markdown]
# ## 🧪 Demo 7: EDA cho Test Dataset
#
# Áp dụng EDA tương tự cho test dataset.

# %%
# Khởi tạo EDA cho test dataset
eda_test = EDA(df_test)

# Tổng quan test dataset
eda_test.overview()
# Out:
# # 📊 Tổng Quan Dữ Liệu
# **📊 Thông tin Dataset**
# <style type="text/css">
# #T_a7aa6 th {
#   background-color: #4CAF50;
#   color: white;
#   font-weight: bold;
#   text-align: center;
#   padding: 10px;
# }
# #T_a7aa6 td {
#   text-align: center;
# }
# #T_a7aa6  {
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_a7aa6_row0_col0 {
#   background-color: #006837;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_a7aa6_row0_col1 {
#   background-color: #b30d26;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_a7aa6_row0_col2 {
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_a7aa6_row0_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_a7aa6_row0_col4 {
#   background-color: #a70226;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# </style>
# <table id="T_a7aa6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a7aa6_level0_col0" class="col_heading level0 col0" >📏 Số dòng</th>
#       <th id="T_a7aa6_level0_col1" class="col_heading level0 col1" >📋 Số cột</th>
#       <th id="T_a7aa6_level0_col2" class="col_heading level0 col2" >💾 Bộ nhớ (MB)</th>
#       <th id="T_a7aa6_level0_col3" class="col_heading level0 col3" >🔢 Biến số</th>
#       <th id="T_a7aa6_level0_col4" class="col_heading level0 col4" >📝 Biến phân loại</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a7aa6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a7aa6_row0_col0" class="data row0 col0" >1459</td>
#       <td id="T_a7aa6_row0_col1" class="data row0 col1" >80</td>
#       <td id="T_a7aa6_row0_col2" class="data row0 col2" >3.42</td>
#       <td id="T_a7aa6_row0_col3" class="data row0 col3" >37</td>
#       <td id="T_a7aa6_row0_col4" class="data row0 col4" >43</td>
#     </tr>
#   </tbody>
# </table>
# **🗂️ Chi tiết các cột**
# <style type="text/css">
# #T_4dec8 th {
#   background-color: #4CAF50;
#   color: white;
#   font-weight: bold;
#   text-align: center;
#   padding: 10px;
# }
# #T_4dec8 td {
#   text-align: center;
# }
# #T_4dec8  {
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_4dec8_row0_col0, #T_4dec8_row0_col1, #T_4dec8_row0_col4, #T_4dec8_row1_col0, #T_4dec8_row1_col1, #T_4dec8_row1_col4, #T_4dec8_row2_col0, #T_4dec8_row2_col1, #T_4dec8_row2_col4, #T_4dec8_row3_col0, #T_4dec8_row3_col1, #T_4dec8_row3_col4, #T_4dec8_row4_col0, #T_4dec8_row4_col1, #T_4dec8_row4_col4, #T_4dec8_row5_col0, #T_4dec8_row5_col1, #T_4dec8_row5_col4, #T_4dec8_row6_col0, #T_4dec8_row6_col1, #T_4dec8_row6_col4, #T_4dec8_row7_col0, #T_4dec8_row7_col1, #T_4dec8_row7_col4, #T_4dec8_row8_col0, #T_4dec8_row8_col1, #T_4dec8_row8_col4, #T_4dec8_row9_col0, #T_4dec8_row9_col1, #T_4dec8_row9_col4, #T_4dec8_row10_col0, #T_4dec8_row10_col1, #T_4dec8_row10_col4, #T_4dec8_row11_col0, #T_4dec8_row11_col1, #T_4dec8_row11_col4, #T_4dec8_row12_col0, #T_4dec8_row12_col1, #T_4dec8_row12_col4, #T_4dec8_row13_col0, #T_4dec8_row13_col1, #T_4dec8_row13_col4, #T_4dec8_row14_col0, #T_4dec8_row14_col1, #T_4dec8_row14_col4, #T_4dec8_row15_col0, #T_4dec8_row15_col1, #T_4dec8_row15_col4, #T_4dec8_row16_col0, #T_4dec8_row16_col1, #T_4dec8_row16_col4, #T_4dec8_row17_col0, #T_4dec8_row17_col1, #T_4dec8_row17_col4, #T_4dec8_row18_col0, #T_4dec8_row18_col1, #T_4dec8_row18_col4, #T_4dec8_row19_col0, #T_4dec8_row19_col1, #T_4dec8_row19_col4, #T_4dec8_row20_col0, #T_4dec8_row20_col1, #T_4dec8_row20_col4, #T_4dec8_row21_col0, #T_4dec8_row21_col1, #T_4dec8_row21_col4, #T_4dec8_row22_col0, #T_4dec8_row22_col1, #T_4dec8_row22_col4, #T_4dec8_row23_col0, #T_4dec8_row23_col1, #T_4dec8_row23_col4, #T_4dec8_row24_col0, #T_4dec8_row24_col1, #T_4dec8_row24_col4, #T_4dec8_row25_col0, #T_4dec8_row25_col1, #T_4dec8_row25_col4, #T_4dec8_row26_col0, #T_4dec8_row26_col1, #T_4dec8_row26_col4, #T_4dec8_row27_col0, #T_4dec8_row27_col1, #T_4dec8_row27_col4, #T_4dec8_row28_col0, #T_4dec8_row28_col1, #T_4dec8_row28_col4, #T_4dec8_row29_col0, #T_4dec8_row29_col1, #T_4dec8_row29_col4, #T_4dec8_row30_col0, #T_4dec8_row30_col1, #T_4dec8_row30_col4, #T_4dec8_row31_col0, #T_4dec8_row31_col1, #T_4dec8_row31_col4, #T_4dec8_row32_col0, #T_4dec8_row32_col1, #T_4dec8_row32_col4, #T_4dec8_row33_col0, #T_4dec8_row33_col1, #T_4dec8_row33_col4, #T_4dec8_row34_col0, #T_4dec8_row34_col1, #T_4dec8_row34_col4, #T_4dec8_row35_col0, #T_4dec8_row35_col1, #T_4dec8_row35_col4, #T_4dec8_row36_col0, #T_4dec8_row36_col1, #T_4dec8_row36_col4, #T_4dec8_row37_col0, #T_4dec8_row37_col1, #T_4dec8_row37_col4, #T_4dec8_row38_col0, #T_4dec8_row38_col1, #T_4dec8_row38_col4, #T_4dec8_row39_col0, #T_4dec8_row39_col1, #T_4dec8_row39_col4, #T_4dec8_row40_col0, #T_4dec8_row40_col1, #T_4dec8_row40_col4, #T_4dec8_row41_col0, #T_4dec8_row41_col1, #T_4dec8_row41_col4, #T_4dec8_row42_col0, #T_4dec8_row42_col1, #T_4dec8_row42_col4, #T_4dec8_row43_col0, #T_4dec8_row43_col1, #T_4dec8_row43_col4, #T_4dec8_row44_col0, #T_4dec8_row44_col1, #T_4dec8_row44_col4, #T_4dec8_row45_col0, #T_4dec8_row45_col1, #T_4dec8_row45_col4, #T_4dec8_row46_col0, #T_4dec8_row46_col1, #T_4dec8_row46_col4, #T_4dec8_row47_col0, #T_4dec8_row47_col1, #T_4dec8_row47_col4, #T_4dec8_row48_col0, #T_4dec8_row48_col1, #T_4dec8_row48_col4, #T_4dec8_row49_col0, #T_4dec8_row49_col1, #T_4dec8_row49_col4, #T_4dec8_row50_col0, #T_4dec8_row50_col1, #T_4dec8_row50_col4, #T_4dec8_row51_col0, #T_4dec8_row51_col1, #T_4dec8_row51_col4, #T_4dec8_row52_col0, #T_4dec8_row52_col1, #T_4dec8_row52_col4, #T_4dec8_row53_col0, #T_4dec8_row53_col1, #T_4dec8_row53_col4, #T_4dec8_row54_col0, #T_4dec8_row54_col1, #T_4dec8_row54_col4, #T_4dec8_row55_col0, #T_4dec8_row55_col1, #T_4dec8_row55_col4, #T_4dec8_row56_col0, #T_4dec8_row56_col1, #T_4dec8_row56_col4, #T_4dec8_row57_col0, #T_4dec8_row57_col1, #T_4dec8_row57_col4, #T_4dec8_row58_col0, #T_4dec8_row58_col1, #T_4dec8_row58_col4, #T_4dec8_row59_col0, #T_4dec8_row59_col1, #T_4dec8_row59_col4, #T_4dec8_row60_col0, #T_4dec8_row60_col1, #T_4dec8_row60_col4, #T_4dec8_row61_col0, #T_4dec8_row61_col1, #T_4dec8_row61_col4, #T_4dec8_row62_col0, #T_4dec8_row62_col1, #T_4dec8_row62_col4, #T_4dec8_row63_col0, #T_4dec8_row63_col1, #T_4dec8_row63_col4 ...
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_4dec8_row0_col2, #T_4dec8_row72_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_4dec8_row0_col3, #T_4dec8_row1_col3, #T_4dec8_row2_col2, #T_4dec8_row2_col3, #T_4dec8_row4_col3, #T_4dec8_row5_col2, #T_4dec8_row5_col3, #T_4dec8_row6_col2, #T_4dec8_row7_col2, #T_4dec8_row7_col3, #T_4dec8_row8_col2, #T_4dec8_row8_col3, #T_4dec8_row9_col2, #T_4dec8_row9_col3, #T_4dec8_row10_col2, #T_4dec8_row10_col3, #T_4dec8_row11_col2, #T_4dec8_row11_col3, #T_4dec8_row12_col3, #T_4dec8_row13_col3, #T_4dec8_row14_col2, #T_4dec8_row14_col3, #T_4dec8_row15_col2, #T_4dec8_row15_col3, #T_4dec8_row16_col3, #T_4dec8_row17_col3, #T_4dec8_row18_col3, #T_4dec8_row19_col3, #T_4dec8_row20_col3, #T_4dec8_row21_col3, #T_4dec8_row22_col2, #T_4dec8_row22_col3, #T_4dec8_row23_col3, #T_4dec8_row24_col3, #T_4dec8_row25_col2, #T_4dec8_row27_col2, #T_4dec8_row27_col3, #T_4dec8_row28_col2, #T_4dec8_row28_col3, #T_4dec8_row29_col3, #T_4dec8_row30_col2, #T_4dec8_row31_col2, #T_4dec8_row32_col2, #T_4dec8_row34_col3, #T_4dec8_row36_col3, #T_4dec8_row37_col3, #T_4dec8_row38_col3, #T_4dec8_row39_col2, #T_4dec8_row39_col3, #T_4dec8_row40_col2, #T_4dec8_row40_col3, #T_4dec8_row41_col2, #T_4dec8_row41_col3, #T_4dec8_row42_col2, #T_4dec8_row42_col3, #T_4dec8_row43_col3, #T_4dec8_row44_col3, #T_4dec8_row45_col3, #T_4dec8_row46_col3, #T_4dec8_row47_col2, #T_4dec8_row47_col3, #T_4dec8_row48_col2, #T_4dec8_row48_col3, #T_4dec8_row49_col2, #T_4dec8_row49_col3, #T_4dec8_row50_col2, #T_4dec8_row50_col3, #T_4dec8_row51_col3, #T_4dec8_row52_col2, #T_4dec8_row52_col3, #T_4dec8_row53_col2, #T_4dec8_row53_col3, #T_4dec8_row54_col3, #T_4dec8_row55_col3, #T_4dec8_row56_col2, #T_4dec8_row56_col3, #T_4dec8_row57_col2, #T_4dec8_row60_col2, #T_4dec8_row61_col3, #T_4dec8_row62_col3, #T_4dec8_row63_col2, #T_4dec8_row64_col2, #T_4dec8_row65_col2, #T_4dec8_row65_col3, #T_4dec8_row66_col3, #T_4dec8_row67_col3, #T_4dec8_row68_col3, #T_4dec8_row69_col3, #T_4dec8_row70_col3, #T_4dec8_row71_col3, #T_4dec8_row72_col2, #T_4dec8_row73_col2, #T_4dec8_row74_col2, #T_4dec8_row75_col3, #T_4dec8_row76_col3, #T_4dec8_row77_col2, #T_4dec8_row77_col3, #T_4dec8_row78_col3, #T_4dec8_row79_col3 {
#   background-color: #a50026;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_4dec8_row1_col2, #T_4dec8_row23_col2, #T_4dec8_row24_col2, #T_4dec8_row26_col3, #T_4dec8_row45_col2, #T_4dec8_row54_col2, #T_4dec8_row69_col2, #T_4dec8_row76_col2 {
#   background-color: #a90426;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_4dec8_row3_col2 {
#   background-color: #cc2627;
#   color: #f1f1
# ## 🔍 Thống Kê Mô Tả
# <style type="text/css">
# #T_cdc76 th {
#   background-color: #4CAF50;
#   color: white;
#   font-weight: bold;
#   text-align: center;
#   padding: 10px;
# }
# #T_cdc76 td {
#   text-align: center;
# }
# #T_cdc76  {
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_cdc76_row0_col0, #T_cdc76_row0_col1, #T_cdc76_row0_col2, #T_cdc76_row0_col3, #T_cdc76_row0_col4, #T_cdc76_row0_col5, #T_cdc76_row0_col6, #T_cdc76_row0_col7, #T_cdc76_row0_col8, #T_cdc76_row0_col9, #T_cdc76_row0_col10, #T_cdc76_row1_col0, #T_cdc76_row1_col1, #T_cdc76_row1_col2, #T_cdc76_row1_col3, #T_cdc76_row1_col4, #T_cdc76_row1_col5, #T_cdc76_row1_col6, #T_cdc76_row1_col7, #T_cdc76_row1_col8, #T_cdc76_row1_col9, #T_cdc76_row1_col10, #T_cdc76_row2_col0, #T_cdc76_row2_col1, #T_cdc76_row2_col2, #T_cdc76_row2_col3, #T_cdc76_row2_col4, #T_cdc76_row2_col5, #T_cdc76_row2_col6, #T_cdc76_row2_col7, #T_cdc76_row2_col8, #T_cdc76_row2_col9, #T_cdc76_row2_col10, #T_cdc76_row3_col0, #T_cdc76_row3_col1, #T_cdc76_row3_col2, #T_cdc76_row3_col3, #T_cdc76_row3_col4, #T_cdc76_row3_col5, #T_cdc76_row3_col6, #T_cdc76_row3_col7, #T_cdc76_row3_col8, #T_cdc76_row3_col9, #T_cdc76_row3_col10, #T_cdc76_row4_col0, #T_cdc76_row4_col1, #T_cdc76_row4_col2, #T_cdc76_row4_col3, #T_cdc76_row4_col4, #T_cdc76_row4_col5, #T_cdc76_row4_col6, #T_cdc76_row4_col7, #T_cdc76_row4_col8, #T_cdc76_row4_col9, #T_cdc76_row4_col10, #T_cdc76_row5_col0, #T_cdc76_row5_col1, #T_cdc76_row5_col2, #T_cdc76_row5_col3, #T_cdc76_row5_col4, #T_cdc76_row5_col5, #T_cdc76_row5_col6, #T_cdc76_row5_col7, #T_cdc76_row5_col8, #T_cdc76_row5_col9, #T_cdc76_row5_col10, #T_cdc76_row6_col0, #T_cdc76_row6_col1, #T_cdc76_row6_col2, #T_cdc76_row6_col3, #T_cdc76_row6_col4, #T_cdc76_row6_col5, #T_cdc76_row6_col6, #T_cdc76_row6_col7, #T_cdc76_row6_col8, #T_cdc76_row6_col9, #T_cdc76_row6_col10, #T_cdc76_row7_col0, #T_cdc76_row7_col1, #T_cdc76_row7_col2, #T_cdc76_row7_col3, #T_cdc76_row7_col4, #T_cdc76_row7_col5, #T_cdc76_row7_col6, #T_cdc76_row7_col7, #T_cdc76_row7_col8, #T_cdc76_row7_col9, #T_cdc76_row7_col10, #T_cdc76_row8_col0, #T_cdc76_row8_col1, #T_cdc76_row8_col2, #T_cdc76_row8_col3, #T_cdc76_row8_col4, #T_cdc76_row8_col5, #T_cdc76_row8_col6, #T_cdc76_row8_col7, #T_cdc76_row8_col8, #T_cdc76_row8_col9, #T_cdc76_row8_col10, #T_cdc76_row9_col0, #T_cdc76_row9_col1, #T_cdc76_row9_col2, #T_cdc76_row9_col3, #T_cdc76_row9_col4, #T_cdc76_row9_col5, #T_cdc76_row9_col6, #T_cdc76_row9_col7, #T_cdc76_row9_col8, #T_cdc76_row9_col9, #T_cdc76_row9_col10, #T_cdc76_row10_col0, #T_cdc76_row10_col1, #T_cdc76_row10_col2, #T_cdc76_row10_col3, #T_cdc76_row10_col4, #T_cdc76_row10_col5, #T_cdc76_row10_col6, #T_cdc76_row10_col7, #T_cdc76_row10_col8, #T_cdc76_row10_col9, #T_cdc76_row10_col10, #T_cdc76_row11_col0, #T_cdc76_row11_col1, #T_cdc76_row11_col2, #T_cdc76_row11_col3, #T_cdc76_row11_col4, #T_cdc76_row11_col5, #T_cdc76_row11_col6, #T_cdc76_row11_col7, #T_cdc76_row11_col8, #T_cdc76_row11_col9, #T_cdc76_row11_col10, #T_cdc76_row12_col0, #T_cdc76_row12_col1, #T_cdc76_row12_col2, #T_cdc76_row12_col3, #T_cdc76_row12_col4, #T_cdc76_row12_col5, #T_cdc76_row12_col6, #T_cdc76_row12_col7, #T_cdc76_row12_col8, #T_cdc76_row12_col9, #T_cdc76_row12_col10, #T_cdc76_row13_col0, #T_cdc76_row13_col1, #T_cdc76_row13_col2, #T_cdc76_row13_col3, #T_cdc76_row13_col4, #T_cdc76_row13_col5, #T_cdc76_row13_col6, #T_cdc76_row13_col7, #T_cdc76_row13_col8, #T_cdc76_row13_col9, #T_cdc76_row13_col10, #T_cdc76_row14_col0, #T_cdc76_row14_col1, #T_cdc76_row14_col2, #T_cdc76_row14_col3, #T_cdc76_row14_col4, #T_cdc76_row14_col5, #T_cdc76_row14_col6, #T_cdc76_row14_col7, #T_cdc76_row14_col8, #T_cdc76_row14_col9, #T_cdc76_row14_col10, #T_cdc76_row15_col0, #T_cdc76_row15_col1, #T_cdc76_row15_col2, #T_cdc76_row15_col3, #T_cdc76_row15_col4, #T_cdc76_row15_col5, #T_cdc76_row15_col6, #T_cdc76_row15_col7, #T_cdc76_row15_col8, #T_cdc76_row15_col9, #T_cdc76_row15_col10, #T_cdc76_row16_col0, #T_cdc76_row16_col1, #T_cdc76_row16_col2, #T_cdc76_row16_col3, #T_cdc76_row16_col4, #T_cdc76_row16_col5, #T_cdc76_row16_col6, #T_cdc76_row16_col7, #T_cdc76_row16_col8, #T_cdc76_row16_col9, #T_cdc76_row16_col10, #T_cdc76_row17_col0, #T_cdc76_row17_col1, #T_cdc76_row17_col2, #T_cdc76_row17_col3, #T_cdc76_row17_col4, #T_cdc76_row17_col5, #T_cdc76_row17_col6, #T_cdc76_row17_col7 ...

# %%
# Phân tích giá trị thiếu trong test dataset
eda_test.missing_values()
# Out:
# ## 🔍 Phân Tích Giá Trị Thiếu
# **📉 Các cột có giá trị thiếu**
# <style type="text/css">
# #T_d63b3 th {
#   background-color: #4CAF50;
#   color: white;
#   font-weight: bold;
#   text-align: center;
#   padding: 10px;
# }
# #T_d63b3 td {
#   text-align: center;
# }
# #T_d63b3  {
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_d63b3_row0_col0, #T_d63b3_row1_col0, #T_d63b3_row2_col0, #T_d63b3_row3_col0, #T_d63b3_row4_col0, #T_d63b3_row5_col0, #T_d63b3_row6_col0, #T_d63b3_row7_col0, #T_d63b3_row8_col0, #T_d63b3_row9_col0, #T_d63b3_row10_col0, #T_d63b3_row11_col0, #T_d63b3_row12_col0, #T_d63b3_row13_col0, #T_d63b3_row14_col0, #T_d63b3_row15_col0, #T_d63b3_row16_col0, #T_d63b3_row17_col0, #T_d63b3_row18_col0, #T_d63b3_row19_col0, #T_d63b3_row20_col0, #T_d63b3_row21_col0, #T_d63b3_row22_col0, #T_d63b3_row23_col0, #T_d63b3_row24_col0, #T_d63b3_row25_col0, #T_d63b3_row26_col0, #T_d63b3_row27_col0, #T_d63b3_row28_col0, #T_d63b3_row29_col0, #T_d63b3_row30_col0, #T_d63b3_row31_col0, #T_d63b3_row32_col0 {
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_d63b3_row0_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_d63b3_row0_col2 {
#   background-color: #c62027;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_d63b3_row1_col1 {
#   background-color: #08773f;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_d63b3_row1_col2, #T_d63b3_row2_col2 {
#   background-color: #c41e27;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_d63b3_row2_col1 {
#   background-color: #128a49;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_d63b3_row3_col1 {
#   background-color: #63bc62;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_d63b3_row3_col2 {
#   background-color: #c01a27;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_d63b3_row4_col1 {
#   background-color: #d1ec86;
#   color: #000000;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_d63b3_row4_col2 {
#   background-color: #b91326;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_d63b3_row5_col1 {
#   background-color: #feffbe;
#   color: #000000;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_d63b3_row5_col2 {
#   background-color: #b50f26;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_d63b3_row6_col1 {
#   background-color: #e65036;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_d63b3_row6_col2, #T_d63b3_row17_col1 {
#   background-color: #a90426;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_d63b3_row7_col1, #T_d63b3_row8_col1, #T_d63b3_row9_col1, #T_d63b3_row10_col1, #T_d63b3_row11_col1 {
#   background-color: #be1827;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_d63b3_row7_col2, #T_d63b3_row8_col2, #T_d63b3_row9_col2, #T_d63b3_row10_col2, #T_d63b3_row11_col2, #T_d63b3_row12_col2, #T_d63b3_row13_col2, #T_d63b3_row14_col2, #T_d63b3_row15_col2, #T_d63b3_row16_col2, #T_d63b3_row17_col2, #T_d63b3_row18_col1, #T_d63b3_row18_col2, #T_d63b3_row19_col1, #T_d63b3_row19_col2, #T_d63b3_row20_col1, #T_d63b3_row20_col2, #T_d63b3_row21_col1, #T_d63b3_row21_col2, #T_d63b3_row22_col1, #T_d63b3_row22_col2, #T_d63b3_row23_col1, #T_d63b3_row23_col2, #T_d63b3_row24_col1, #T_d63b3_row24_col2, #T_d63b3_row25_col1, #T_d63b3_row25_col2, #T_d63b3_row26_col1, #T_d63b3_row26_col2, #T_d63b3_row27_col1, #T_d63b3_row27_col2, #T_d63b3_row28_col1, #T_d63b3_row28_col2, #T_d63b3_row29_col1, #T_d63b3_row29_col2, #T_d63b3_row30_col1, #T_d63b3_row30_col2, #T_d63b3_row31_col1, #T_d63b3_row31_col2, #T_d63b3_row32_col1, #T_d63b3_row32_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_d63b3_row12_col1, #T_d63b3_row13_col1, #T_d63b3_row14_col1, #T_d63b3_row15_col1, #T_d63b3_row16_col1 {
#   background-color: #b30d26;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# </style>
# <table id="T_d63b3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d63b3_level0_col0" class="col_heading level0 col0" >Cột</th>
#       <th id="T_d63b3_level0_col1" class="col_heading level0 col1" >Số lượng thiếu</th>
#       <th id="T_d63b3_level0_col2" class="col_heading level0 col2" >% thiếu</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d63b3_level0_row0" class="row_heading level0 row0" >72</th>
#       <td id="T_d63b3_row0_col0" class="data row0 col0" >PoolQC</td>
#       <td id="T_d63b3_row0_col1" class="data row0 col1" >1456</td>
#       <td id="T_d63b3_row0_col2" class="data row0 col2" >99.790000</td>
#     </tr>
#     <tr>
#       <th id="T_d63b3_level0_row1" class="row_heading level0 row1" >74</th>
#       <td id="T_d63b3_row1_col0" class="data row1 col0" >MiscFeature</td>
#       <td id="T_d63b3_row1_col1" class="data row1 col1" >1408</td>
#       <td id="T_d63b3_row1_col2" class="data row1 col2" >96.500000</td>
#     </tr>
#     <tr>
#       <th id="T_d63b3_level0_row2" class="row_heading level0 row2" >6</th>
#       <td id="T_d63b3_row2_col0" class="data row2 col0" >Alley</td>
#       <td id="T_d63b3_row2_col1" class="data row2 col1" >1352</td>
#       <td id="T_d63b3_row2_col2" class="data row2 col2" >92.670000</td>
#     </tr>
#     <tr>
#       <th id="T_d63b3_level0_row3" class="row_heading level0 row3" >73</th>
#       <td id="T_d63b3_row3_col0" class="data row3 col0" >Fence</td>
#       <td id="T_d63b3_row3_col1" class="data row3 col1" >1169</td>
#       <td id="T_d63b3_row3_col2" class="data row3 col2" >80.120000</td>
#     </tr>
#     <tr>
#       <th id="T_d63b3_level0_row4" class="row_heading level0 row4" >25</th>
#       <td id="T_d63b3_row4_col0" class="data row4 col0" >MasVnrType</td>
#       <td id="T_d63b3_row4_col1" class="data row4 col1" >894</td>
#       <td id="T_d63b3_row4_col2" class="data row4 col2" >61.270000</td>
#     </tr>
#     <tr>
#       <th id="T_d63b3_level0_row5" class="row_heading level0 row5" >57</th>
#       <td id="T_d63b3_row5_col0" class="data row5 col0" >FireplaceQu</td>
#       <td id="T_d63b3_row5_col1" class="data row5 col1" >730</td>
#       <td id="T_d63b3_row5_col2" class="data row5 col2" >50.030000</td>
#     </tr>
#     <tr>
#       <th id="T_d63b3_level0_row6" class="row_heading level0 row6" >3</th>
#       <td id="T_d63b3_row6_col0" class="data row6 col0" >LotFrontage</td>
#       <td id="T_d63b3_row6_col1" class="data row6 col1" >227</td>
#       <td id="T_d63b3_row6_col2" class="data row6 col2" >15.560000</td>
#     </tr>
#     <tr>
#       <th id="T_d63b3_level0_row7" class="row_heading level0 row7" >63</th>
#       <td id="T_d63b3_row7_col0" class="data row7 col0" >GarageQual</td>
#       <td id="T_d63b3_row7_col1" class="data row7 col1" >78</td>
#       <td id="T_d63b3_row7_col2" class="data row7 col2" >5.350000</td>
#     </tr>
#     <tr>
#       <th id="T_d63b3_level0_row8" class="row_heading level0 row8" >64</th>
#       <td id="T_d63b3_row8_col0" class="data row8 col0" >GarageCond</td>
#       <td id="T_d63b3_row8_col1" class="data row8 col1" >78</td>
#       <td id="T_d63b3_row8_col2" class="data row8 col2" >5.350000</td>
#     </tr>
#     <tr>
#       <th id="T_d63b3_level0_row9" class="row_heading level0 row9" >59</th>
#       <td id="T_d63b3_row9_col0" class="data row9 col0" >GarageYrBlt</td>
#       <td id="T_d63b3_row9_col1" class="data row9 col1" >78</td>
#       <td id="T_d63b3_row9_col2" class="data row9 col2" >5.350000</td>
#     </tr>
#     <tr>
#       <th id="T_d63b3_level0_row10" class="row_heading level0 row10" >60</th>
#       <td id="T_d63b3_row10_col0" class="data row10 col0" >GarageFinish</td>
#       <td id="T_d63b3_row10_col1" class="data row10 col1" >78</td>
#       <td id="T_d63b3_row10_col2" class="data row10 col2" >5.350000</td>
#     </tr>
#     <tr>
#       <th id="T_d63b3_level0_row11" class="row_heading level0 row11" >58</th>

# %%
# Phân bố một số biến trong test dataset
eda_test.distribution('GrLivArea', interactive=True)
# Out:
# ### ✨ Phân Bố: GrLivArea
# **📊 Thống kê GrLivArea**
# <style type="text/css">
# #T_10678 th {
#   background-color: #4CAF50;
#   color: white;
#   font-weight: bold;
#   text-align: center;
#   padding: 10px;
# }
# #T_10678 td {
#   text-align: center;
# }
# #T_10678  {
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_10678_row0_col0 {
#   background-color: #fca85e;
#   color: #000000;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_10678_row0_col1 {
#   background-color: #fba05b;
#   color: #000000;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_10678_row0_col2 {
#   background-color: #d42d27;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_10678_row0_col3 {
#   background-color: #cc2627;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_10678_row0_col4 {
#   background-color: #006837;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_10678_row0_col5 {
#   background-color: #a50026;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# </style>
# <table id="T_10678">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_10678_level0_col0" class="col_heading level0 col0" >Mean</th>
#       <th id="T_10678_level0_col1" class="col_heading level0 col1" >Median</th>
#       <th id="T_10678_level0_col2" class="col_heading level0 col2" >Std</th>
#       <th id="T_10678_level0_col3" class="col_heading level0 col3" >Min</th>
#       <th id="T_10678_level0_col4" class="col_heading level0 col4" >Max</th>
#       <th id="T_10678_level0_col5" class="col_heading level0 col5" >Skewness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_10678_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_10678_row0_col0" class="data row0 col0" >1486.045922</td>
#       <td id="T_10678_row0_col1" class="data row0 col1" >1432.000000</td>
#       <td id="T_10678_row0_col2" class="data row0 col2" >485.566099</td>
#       <td id="T_10678_row0_col3" class="data row0 col3" >407</td>
#       <td id="T_10678_row0_col4" class="data row0 col4" >5095</td>
#       <td id="T_10678_row0_col5" class="data row0 col5" >1.130402</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Phân tích biến phân loại trong test dataset
eda_test.categorical_summary('Neighborhood', top_n=10)
# Out:
# ### ✨ Phân Tích: Neighborhood
# **📋 Bảng tần suất Neighborhood**
# <style type="text/css">
# #T_933e5 th {
#   background-color: #4CAF50;
#   color: white;
#   font-weight: bold;
#   text-align: center;
#   padding: 10px;
# }
# #T_933e5 td {
#   text-align: center;
# }
# #T_933e5  {
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_933e5_row0_col0, #T_933e5_row1_col0, #T_933e5_row2_col0, #T_933e5_row3_col0, #T_933e5_row4_col0, #T_933e5_row5_col0, #T_933e5_row6_col0, #T_933e5_row7_col0, #T_933e5_row8_col0, #T_933e5_row9_col0 {
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_933e5_row0_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_933e5_row0_col2 {
#   background-color: #bd1726;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_933e5_row1_col1 {
#   background-color: #e5f49b;
#   color: #000000;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_933e5_row1_col2 {
#   background-color: #af0926;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_933e5_row2_col1 {
#   background-color: #f5fbb2;
#   color: #000000;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_933e5_row2_col2 {
#   background-color: #ad0826;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_933e5_row3_col1 {
#   background-color: #fee999;
#   color: #000000;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_933e5_row3_col2, #T_933e5_row4_col2 {
#   background-color: #a90426;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_933e5_row4_col1 {
#   background-color: #fee695;
#   color: #000000;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_933e5_row5_col1 {
#   background-color: #fede89;
#   color: #000000;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_933e5_row5_col2, #T_933e5_row6_col2 {
#   background-color: #a70226;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_933e5_row6_col1 {
#   background-color: #fed683;
#   color: #000000;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_933e5_row7_col1 {
#   background-color: #fdc171;
#   color: #000000;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_933e5_row7_col2, #T_933e5_row8_col2, #T_933e5_row9_col2 {
#   background-color: #a50026;
#   color: #f1f1f1;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_933e5_row8_col1 {
#   background-color: #fca55d;
#   color: #000000;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# #T_933e5_row9_col1 {
#   background-color: #fba35c;
#   color: #000000;
#   border: 1px solid #ddd;
#   padding: 8px;
#   text-align: center;
# }
# </style>
# <table id="T_933e5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_933e5_level0_col0" class="col_heading level0 col0" >Giá trị</th>
#       <th id="T_933e5_level0_col1" class="col_heading level0 col1" >Số lượng</th>
#       <th id="T_933e5_level0_col2" class="col_heading level0 col2" >Tỷ lệ %</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_933e5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_933e5_row0_col0" class="data row0 col0" >NAmes</td>
#       <td id="T_933e5_row0_col1" class="data row0 col1" >218</td>
#       <td id="T_933e5_row0_col2" class="data row0 col2" >14.940000</td>
#     </tr>
#     <tr>
#       <th id="T_933e5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_933e5_row1_col0" class="data row1 col0" >OldTown</td>
#       <td id="T_933e5_row1_col1" class="data row1 col1" >126</td>
#       <td id="T_933e5_row1_col2" class="data row1 col2" >8.640000</td>
#     </tr>
#     <tr>
#       <th id="T_933e5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_933e5_row2_col0" class="data row2 col0" >CollgCr</td>
#       <td id="T_933e5_row2_col1" class="data row2 col1" >117</td>
#       <td id="T_933e5_row2_col2" class="data row2 col2" >8.020000</td>
#     </tr>
#     <tr>
#       <th id="T_933e5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_933e5_row3_col0" class="data row3 col0" >Somerst</td>
#       <td id="T_933e5_row3_col1" class="data row3 col1" >96</td>
#       <td id="T_933e5_row3_col2" class="data row3 col2" >6.580000</td>
#     </tr>
#     <tr>
#       <th id="T_933e5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_933e5_row4_col0" class="data row4 col0" >Edwards</td>
#       <td id="T_933e5_row4_col1" class="data row4 col1" >94</td>
#       <td id="T_933e5_row4_col2" class="data row4 col2" >6.440000</td>
#     </tr>
#     <tr>
#       <th id="T_933e5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_933e5_row5_col0" class="data row5 col0" >NridgHt</td>
#       <td id="T_933e5_row5_col1" class="data row5 col1" >89</td>
#       <td id="T_933e5_row5_col2" class="data row5 col2" >6.100000</td>
#     </tr>
#     <tr>
#       <th id="T_933e5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_933e5_row6_col0" class="data row6 col0" >Gilbert</td>
#       <td id="T_933e5_row6_col1" class="data row6 col1" >86</td>
#       <td id="T_933e5_row6_col2" class="data row6 col2" >5.890000</td>
#     </tr>
#     <tr>
#       <th id="T_933e5_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_933e5_row7_col0" class="data row7 col0" >Sawyer</td>
#       <td id="T_933e5_row7_col1" class="data row7 col1" >77</td>
#       <td id="T_933e5_row7_col2" class="data row7 col2" >5.280000</td>
#     </tr>
#     <tr>
#       <th id="T_933e5_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_933e5_row8_col0" class="data row8 col0" >SawyerW</td>
#       <td id="T_933e5_row8_col1" class="data row8 col1" >66</td>
#       <td id="T_933e5_row8_col2" class="data row8 col2" >4.520000</td>
#     </tr>
#     <tr>
#       <th id="T_933e5_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_933e5_row9_col0" class="data row9 col0" >Mitchel</td>
#       <td id="T_933e5_row9_col1" class="data row9 col1" >65</td>
#       <td id="T_933e5_row9_col2" class="data row9 col2" >4.460000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 🎨 Demo 8: So Sánh Train vs Test
#
# So sánh phân phối của các biến quan trọng giữa train và test dataset.

# %%
# So sánh phân phối GrLivArea giữa train và test
import plotly.graph_objects as go

fig = go.Figure()

# Train data
fig.add_trace(go.Histogram(
    x=df_train['GrLivArea'],
    name='Train',
    marker_color='lightblue',
    opacity=0.7,
    nbinsx=30
))

# Test data
fig.add_trace(go.Histogram(
    x=df_test['GrLivArea'],
    name='Test',
    marker_color='lightcoral',
    opacity=0.7,
    nbinsx=30
))

fig.update_layout(
    title="📊 So Sánh Phân Bố GrLivArea: Train vs Test",
    xaxis_title="GrLivArea",
    yaxis_title="Frequency",
    barmode='overlay',
    template="plotly_white",
    height=500
)

fig.show()

# %%
# So sánh phân phối OverallQual
fig = go.Figure()

# Train data
train_counts = df_train['OverallQual'].value_counts().sort_index()
fig.add_trace(go.Bar(
    x=train_counts.index,
    y=train_counts.values,
    name='Train',
    marker_color='lightblue',
    opacity=0.7
))

# Test data
test_counts = df_test['OverallQual'].value_counts().sort_index()
fig.add_trace(go.Bar(
    x=test_counts.index,
    y=test_counts.values,
    name='Test',
    marker_color='lightcoral',
    opacity=0.7
))

fig.update_layout(
    title="📊 So Sánh Phân Bố OverallQual: Train vs Test",
    xaxis_title="OverallQual",
    yaxis_title="Count",
    barmode='group',
    template="plotly_white",
    height=500
)

fig.show()

# %% [markdown]
# ## ✅ Kết Luận
#
# Module EDA đã được demo thành công với các chức năng:
# - ✅ Tổng quan dữ liệu (`overview()`)
# - ✅ Phân tích giá trị thiếu (`missing_values()`)
# - ✅ Phân bố biến số (`distribution()`)
# - ✅ Ma trận tương quan (`correlation_matrix()`)
# - ✅ Phân tích biến phân loại (`categorical_summary()`)
# - ✅ Phát hiện ngoại lai (`outlier_detection()`)
# - ✅ So sánh train vs test dataset
#
# Module cung cấp visualizations đẹp mắt và interactive với Plotly! 🎉
